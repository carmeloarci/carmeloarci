# %% [markdown]
# <a href="https://colab.research.google.com/github/carmeloarci/carmeloarci/blob/main/AFOSC_POL_pipe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# =============================================================================
# AFOSC_POL_pipe.ipynb
# =============================================================================
# Scopo:
#
# Il codice realizza le procedure di riduzione e analisi dei dati polarimetrici acquisiti con AFOSC
# (Asiago Faint Object Spectrograph and Camera) installato al telescopio Copernico (1.82 m, Cima Ekar).
# In particolare, il notebook permette:
#   - la calibrazione fotometrica e polarimetrica delle immagini,
#   - l’estrazione dei parametri di Stokes (I, Q, U),
#   - la ricostruzione del grado e dell’angolo di polarizzazione lineare,
#   - la visualizzazione diagnostica dei risultati.
#
#
# Autore: Dr Matteo Simioni, Dr Luca Cortese, Dr. Carmelo Arcidiacono
# INAF – Osservatorio Astronomico di Padova
# Data: Ottobre 2025
# =============================================================================# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Install missing package
# !pip install photutils astropy matplotlib
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Requirement already satisfied: photutils in /usr/local/lib/python3.12/dist-packages (2.3.0)
# Requirement already satisfied: astropy in /usr/local/lib/python3.12/dist-packages (7.1.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: numpy>=1.25 in /usr/local/lib/python3.12/dist-packages (from photutils) (2.0.2)
# Requirement already satisfied: scipy>=1.11.1 in /usr/local/lib/python3.12/dist-packages (from photutils) (1.16.3)
# Requirement already satisfied: pyerfa>=2.0.1.1 in /usr/local/lib/python3.12/dist-packages (from astropy) (2.0.1.5)
# Requirement already satisfied: astropy-iers-data>=0.2025.9.29.0.35.48 in /usr/local/lib/python3.12/dist-packages (from astropy) (0.2025.10.27.0.39.10)
# Requirement already satisfied: PyYAML>=6.0.0 in /usr/local/lib/python3.12/dist-packages (from astropy) (6.0.3)
# Requirement already satisfied: packaging>=22.0.0 in /usr/local/lib/python3.12/dist-packages (from astropy) (25.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
import os
import glob
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits
from astropy.stats import SigmaClip
from photutils.background import MedianBackground
from photutils.segmentation import detect_sources, SourceCatalog
from photutils.aperture import CircularAperture, CircularAnnulus, aperture_photometry
from scipy.spatial import cKDTree
from datetime import datetime
import matplotlib.patches as patches
import ipywidgets as widgets
from IPython.display import display, clear_output
from photutils.centroids import centroid_com
from astropy.stats import SigmaClip
import numpy as np
from photutils.aperture import CircularAperture, CircularAnnulus, aperture_photometry
import gc
from astropy.stats import sigma_clip

# %%
# --- FUNCTIONS ---
# ---------------------------------------------------------------------------
# detect_sources_in_image
# ---------------------------------------------------------------------------
# Detects astronomical sources within predefined Regions of Interest (ROIs)
# in the AFOSC image. Each ROI corresponds to one of the four polarimetric
# beams (0°, 90°, 45°, 135°). A mask is built to restrict source detection
# only to these regions, and the photutils segmentation algorithm identifies
# connected pixels above the given threshold. The resulting centroids define
# candidate target positions for photometric measurement in each beam.
# ---------------------------------------------------------------------------

def detect_sources_in_image(data_norm, threshold, npixels, roi_origins, roi_w, roi_h):
    """
    Detects sources inside the specified ROIs using photutils segmentation.
    Returns: ndarray of shape (N, 2) with centroids; if no sources, returns array of shape (0, 2).
    """
    from astropy.stats import sigma_clip
    # 1) Maschera ROI
    mask = np.zeros_like(data_norm, dtype=bool)
    for (rx, ry) in roi_origins:
        mask[ry:ry + roi_h, rx:rx + roi_w] = True
    data_masked = np.where(mask, data_norm, 0)
    # ===============================================================
    # 🔹 Rimozione del fondo colonnare con media (3σ clipping superiore)
    # ===============================================================
    data_corrected = data_masked.copy()

    n_cols = data_corrected.shape[1]
    for col in range(n_cols):
        col_data = data_corrected[:, col]

        # Considera solo pixel > 0
        col_valid = col_data[col_data > 0]

        if len(col_valid) >= 10:
            # Clipping solo sul lato superiore (elimina stelle)
            clipped = sigma_clip(col_valid, sigma_upper=3.0, sigma_lower=None, maxiters=5)
            sky_mean = np.mean(clipped.data[~clipped.mask])
        else:
            # Se pochi pixel validi, usa la mediana grezza
            sky_mean = np.median(col_valid) if len(col_valid) > 0 else 0.0

        # Sottrai il valore del cielo dalla colonna
        data_corrected[:, col] = col_data - sky_mean

    # 🔹 RIMOZIONE BANDA ORIZZONTALE (mediana per riga)
    row_med = np.where(mask, data_corrected, np.nan)
    row_med = np.nanmedian(row_med, axis=1)          # mediana su ciascuna riga
    data_corrected = data_masked - row_med[:, None]
    # Aggiorna immagine per la segmentazione

    data_masked = data_corrected

    # ===============================================================
    # 2) Segmentazione
    try:
        segm = detect_sources(data_masked, threshold, npixels=npixels)
    except Exception as e:
        print(f"[Error] detect_sources() failed: {e}")
        return np.empty((0, 2), dtype=float)

    # 3) Validazione segm
    if segm is None or getattr(segm, "data", None) is None or not np.any(segm.data > 0):
        print("[Info] No segments detected inside ROIs.")
        return np.empty((0, 2), dtype=float)

    '''# 4) Catalogo
    try:
        catalog = SourceCatalog(data_masked, segm)
    except Exception as e:
        print(f"[Error] Could not create SourceCatalog: {e}")
        return np.empty((0, 2), dtype=float) '''

    del data_corrected
    # 4) Catalogo
    try:
        catalog = SourceCatalog(data_masked, segm)
        del data_masked
        del segm
        gc.collect()
    except Exception as e:
        print(f"[Error] Could not create SourceCatalog: {e}")
        return np.empty((0, 2), dtype=float)

    '''# 🔹 FILTRO MORFOLOGICO ANTI-TRAIL
    MIN_AREA = 5          # px
    MAX_AREA = 400        # px  (aumenta se la PSF è molto larga)
    MAX_ELONG = 1.8       # rapporto assi; >2 tipico di scie/colonne
    SAT_LEVEL = 55000.0   # ADU circa; regola con il tuo gain/dinamica

    filtered = []
    for p in catalog:
        try:
            area = float(getattr(p, "area", np.nan))
            elong = float(getattr(p, "elongation", np.nan))
            peak  = float(getattr(p, "max_value", np.nan))
            x = float(getattr(p.xcentroid, "value", p.xcentroid))
            y = float(getattr(p.ycentroid, "value", p.ycentroid))

            if not (np.isfinite([area, elong, peak, x, y]).all()):
                continue
            if area < MIN_AREA or area > MAX_AREA:
                continue
            if elong > MAX_ELONG:
                continue
            # opzionale: scarta scie sature e molto allungate
            if peak > SAT_LEVEL and elong > 1.5:
                continue

            filtered.append((x, y))
        except Exception:
            continue

    coords = np.array(filtered, dtype=float).reshape(-1, 2)
    print(f"[Info] Detected {len(coords)} stellar-like sources after shape filtering.")'''

    # 5) Centroidi (x, y)
    coords = []
    for p in catalog:
        try:
            x = float(getattr(p.xcentroid, "value", p.xcentroid))
            y = float(getattr(p.ycentroid, "value", p.ycentroid))
            if np.isfinite(x) and np.isfinite(y):
                coords.append((x, y))
        except Exception:
            continue

    coords = np.array(coords, dtype=float).reshape(-1, 2)
    print(f"[Info] Detected {len(coords)} sources in defined ROIs.")

    # 🔹 Aggiunta: stampa dettagliata delle coordinate
    if len(coords) > 0:
        for i, (x, y) in enumerate(coords, start=1):
            print(f"  ROI {i}: x = {x:.2f}, y = {y:.2f}")
    else:
        print("  Nessuna sorgente rilevata.")
    return coords


# ---------------------------------------------------------------------------
# iterative_aperture_selection
# ---------------------------------------------------------------------------
# Determines the optimal aperture radius for flux extraction by iteratively
# enlarging the aperture until the relative change in enclosed flux is below
# a given fractional threshold (f_threshold). This approach avoids either
# underestimating or over-integrating the stellar flux. The routine also
# estimates the mean and RMS background level from an annulus surrounding
# the source, to be subtracted during flux computation.
# ---------------------------------------------------------------------------

def iterative_aperture_selection(data, x, y, f_threshold=0.01, max_iter=50):
    """
    Iteratively find the optimal aperture radius where the enclosed flux converges
    (relative change below f_threshold) while computing a robust local background.

    The iteration continues even if negative fluxes are encountered,
    keeping track of the last positive measurement.
    """

    scale_in_factor = 1.
    scale_out_factor = 2.
    r_ap = 2.0
    prev_flux = None
    last_valid = None  # memorizza ultima misura positiva
    sigma_clip = SigmaClip(sigma=3.0, maxiters=5)
    print(f"[DEBUG] In iterative: median={np.median(data):.2f}, min={data.min():.2f}, max={data.max():.2f}")

    for i in range(max_iter):
        # Definizione aperture e annulus
        aperture = CircularAperture((x, y), r=r_ap)
        annulus_ap = CircularAnnulus((x, y),
                                     r_in=scale_in_factor * r_ap,
                                     r_out=scale_out_factor * r_ap)
        annulus_mask = annulus_ap.to_mask(method='center')

        annulus_data = annulus_mask.multiply(data)
        annulus_data_1d = annulus_data[annulus_mask.data > 0]

        # Stima robusta del fondo
        if annulus_data_1d.size > 0 and np.isfinite(annulus_data_1d).any():
            clipped = sigma_clip(annulus_data_1d)
            valid = clipped[~clipped.mask]
            bkg_mean = np.mean(valid)
            bkg_rms = np.std(valid)
        else:
            bkg_mean, bkg_rms = 0.0, 0.0
            print(f"[Warning] No valid background pixels at ({x:.1f},{y:.1f})")

        # Fotometria
        phot_table = aperture_photometry(data, aperture)
        flux = phot_table['aperture_sum'][0] - bkg_mean * aperture.area

        # Controllo validità
        if not np.isfinite(flux):
            print(f"[Warning] Invalid flux (NaN/inf) at r={r_ap:.1f} for ({x:.1f},{y:.1f}); continuing.")
            r_ap += 1.0
            continue

        if flux <= 0:
            print(f"[Info] Negative flux ({flux:.2f}) at r={r_ap:.1f} for ({x:.1f},{y:.1f}); continuing. phot_table {phot_table['aperture_sum'][0]:.2f}, bkg_mean {bkg_mean:.2f}, aperture.area {aperture.area:.2f})")
            r_ap += 1.0
            continue

        # Flusso positivo → memorizza
        last_valid = (r_ap, scale_out_factor * r_ap, bkg_mean, bkg_rms)
        # Test di convergenza
        if prev_flux is not None:
            if abs(flux - prev_flux) / max(abs(flux), 1e-8) <= f_threshold:
                # print(f"[OK] Converged at r={r_ap:.1f} for ({x:.1f},{y:.1f})")
                return r_ap, scale_out_factor * r_ap, bkg_mean, bkg_rms

        prev_flux = flux
        r_ap += 1.0

    # Se non converge ma ci sono stati valori positivi → restituisci l’ultimo valido
    if last_valid is not None:
        print(f"[Info] No convergence but returning last positive flux at r={last_valid[0]:.1f} for ({x:.1f},{y:.1f})")
        return last_valid

    print(f"[Warning] No valid (positive) flux found for source at ({x:.1f},{y:.1f})")
    return None, None, None, None

# ---------------------------------------------------------------------------
# measure_fluxes_all_rois
# ---------------------------------------------------------------------------
# Performs aperture photometry for all four polarimetric ROIs using the
# positions of the selected target in each beam. For each ROI it measures:
#   - the integrated source flux corrected for background,
#   - the chosen aperture and background annulus radii,
#   - the local background mean and noise.
# Returns arrays of these quantities to be used in the Stokes computation.
# ---------------------------------------------------------------------------

def measure_fluxes_all_rois(data, selected_coords, f_threshold=0.01):
    """
    Measures flux and background stats for all selected sources (4 ROIs).
    Ensures consistent aperture and background annulus across all ROIs.
    Returns:
      fluxes: list of fluxes (I0, I90, I45, I135)
      aperture_radii: list of aperture radii
      annulus_radii: list of outer radii for background annulus
      bkg_means: list of mean background values
      bkg_rms: list of background RMS values (per pixel)
    """

    fluxes = []
    aperture_radii = []
    annulus_radii = []
    bkg_means = []
    bkg_rms = []
    refined_coords = []

    # --- STEP 1: misura preliminare per ciascuna ROI ---
    for i, (x, y) in enumerate(selected_coords):
        x_refined, y_refined = recenter_source(data, x, y, box=10)
        refined_coords.append((x_refined, y_refined))
        print(f"ROI {i} initial ({x:.1f},{y:.1f}) → refined ({x_refined:.1f},{y_refined:.1f})")

        r_ap, r_annulus_out, bkg_mean, bkg_std = iterative_aperture_selection(
            data, x_refined, y_refined, f_threshold=f_threshold
        )

        if r_ap is None:
            print(f"[Warning] Failed to find aperture radius for ROI {i} ({x:.1f},{y:.1f}) → skipping measurement.")
            return None, None, None, None, None

        aperture_radii.append(r_ap)
        annulus_radii.append(r_annulus_out)
        bkg_means.append(bkg_mean)
        bkg_rms.append(bkg_std)

    # --- STEP 2: determina raggi comuni ---
    r_ap_min = np.min(aperture_radii)
    r_ap_max = np.max(aperture_radii)
    r_annulus_min = np.min(annulus_radii)
    print(f"[INFO] Using common aperture radius = {r_ap_max:.2f} px, annulus outer radius = {r_annulus_min:.2f} px, minimum radii was {r_ap_min:.2f}")

    # --- STEP 3: ricalcola flussi con raggi comuni ---
    fluxes = []
    aperture_radii_common = []
    annulus_radii_common = []
    bkg_means_common = []
    bkg_rms_common = []

    for i, (x_refined, y_refined) in enumerate(refined_coords):
        # Garantisce geometria valida: r_out > r_in
        r_in = 1.5 * r_ap_max
        r_out = max(r_in + 1.0, r_annulus_min)  # forza r_out > r_in

        aperture = CircularAperture((x_refined, y_refined), r=r_ap_max)
        annulus_ap = CircularAnnulus(
            (x_refined, y_refined),
            r_in=r_in,
            r_out=r_out
        )

        # Estrai fondo locale coerente con la stessa geometria
        annulus_mask = annulus_ap.to_mask(method='center')
        annulus_data = annulus_mask.multiply(data)
        annulus_data_1d = annulus_data[annulus_mask.data > 0]

        if annulus_data_1d.size > 0 and np.isfinite(annulus_data_1d).any():
            clipped = SigmaClip(sigma=3.0, maxiters=5)(annulus_data_1d)
            valid = clipped[~clipped.mask]
            local_bkg_mean = np.mean(valid)
            local_bkg_std = np.std(valid)
        else:
            local_bkg_mean, local_bkg_std = 0.0, 0.0
            print(f"[Warning] No valid background pixels for ROI {i}.")

        # Fotometria coerente
        phot_table = aperture_photometry(data, aperture)
        flux = phot_table['aperture_sum'][0] - local_bkg_mean * aperture.area

        fluxes.append(flux)
        aperture_radii_common.append(r_ap_min)
        annulus_radii_common.append(r_annulus_min)
        bkg_means_common.append(local_bkg_mean)
        bkg_rms_common.append(local_bkg_std)

        print(f"ROI {i}: flux={flux:.1f}, Bkg={local_bkg_mean:.2f}, RMS={local_bkg_std:.2f}")

    return (
        fluxes,
        aperture_radii_common,
        annulus_radii_common,
        bkg_means_common,
        bkg_rms_common
    )
#---------------------------------------------------------------------------
# compute_stokes_parameters
# ---------------------------------------------------------------------------
# Computes the normalized Stokes parameters (Q, U) and the derived degree (P)
# and position angle (θ) of linear polarization, from the four measured
# intensities (I0, I90, I45, I135). This follows the standard formulae:
#   Q = (I0 - I90) / (I0 + I90)
#   U = (I45 - I135) / (I45 + I135)
#   P = sqrt(Q² + U²)
#   θ = 0.5 * arctan(U / Q)
# The function is central to the polarimetric analysis.
# ---------------------------------------------------------------------------
def compute_stokes_parameters(fluxes):
    I0, I90, I45, I135 = fluxes
    Q = (I0 - I90) / (I0 + I90)
    U = (I45 - I135) / (I45 + I135)
    P = np.sqrt(Q**2 + U**2)
    theta = 0.5 * np.degrees(np.arctan2(U, Q))
    return Q, U, P, theta
# ---------------------------------------------------------------------------
# match_source_in_new_image
# ---------------------------------------------------------------------------
# Tracks the same astrophysical source across successive FITS images,
# by matching its previously measured position with detections in a new frame.
# It uses a k-d tree nearest-neighbour search (cKDTree) to find the closest
# match within a maximum allowed displacement (max_move) inside each ROI.
# This enables automatic source tracking between exposures, avoiding repeated
# manual selection.
# ---------------------------------------------------------------------------

def match_source_in_new_image(prev_pos, catalog_coords, roi_origins, roi_w, roi_h, dx, gap, max_move=50):
    """
    Try to match the previously selected source position in a new image.
    Returns selected_coords if match is within max_move px, else None.
    """
    if prev_pos is None or len(prev_pos) == 0:
        return None # Cannot match if no previous position

    rx0, ry0 = roi_origins[0]
    inside_roi0_mask = (
        (catalog_coords[:,0] >= rx0) & (catalog_coords[:,0] <= rx0 + roi_w) &
        (catalog_coords[:,1] >= ry0) & (catalog_coords[:,1] <= ry0 + roi_h)
    )
    roi0_coords = catalog_coords[inside_roi0_mask]
    if len(roi0_coords) == 0:
        return None

    tree_roi0 = cKDTree(roi0_coords)
    # Ensure prev_pos[0] is a 2-element array
    if not isinstance(prev_pos, np.ndarray) or prev_pos.shape != (4, 2):
         return None # previous position is not in the expected format

    dist, idx = tree_roi0.query(prev_pos[0]) # prev_pos[0] is the coordinate in ROI 0
    if dist > max_move:
        return None

    base_source = roi0_coords[idx]
    selected_coords = [base_source]

    for i in range(1,4):
        rx, ry = roi_origins[i]
        if i < 2:
            x_shift = i * dx
        else:
            x_shift = i * dx + gap
        target_x = base_source[0] + x_shift
        target_y = base_source[1]

        inside_roi_mask = (
            (catalog_coords[:,0] >= rx) & (catalog_coords[:,0] <= rx + roi_w) &
            (catalog_coords[:,1] >= ry) & (catalog_coords[:,1] <= ry + roi_h)
        )
        roi_coords = catalog_coords[inside_roi_mask]
        if len(roi_coords) == 0:
            return None

        roi_tree = cKDTree(roi_coords)
        dist_i, idx_i = roi_tree.query([target_x, target_y], k=1)
        if dist_i > max_move:
            return None

        match_source = roi_coords[idx_i]
        selected_coords.append(match_source)

    return np.array(selected_coords) # Return as numpy array

def recenter_source(data, x0, y0, box=10):
        """
        Refine the centroid around an initial guess (x0, y0) using
        the center-of-mass method inside a small box.
        """
        x0, y0 = int(round(x0)), int(round(y0))
        y1, y2 = max(y0 - box, 0), min(y0 + box, data.shape[0])
        x1, x2 = max(x0 - box, 0), min(x0 + box, data.shape[1])
        sub = data[y1:y2, x1:x2]
        if sub.size == 0 or not np.isfinite(sub).any():
            return x0, y0  # fallback
        dy, dx = centroid_com(sub)
        return x1 + dx, y1 + dy
import numpy as np

def compute_stokes_dw(
    fluxes,
    gains=None,
    q_inst=0.0, u_inst=0.0,     # instrumental polarization to subtract (in Q,U)
    theta0_deg=0.0,             # angle zero-point (degrees) to rotate the vector (not used here)
    p_debias=True,              # Wardle & Kronberg debias
):
    """
    Stokes from a double-Wollaston single exposure (four beams: 0,90,45,135).

    Parameters
    ----------
    fluxes : iterable of 4 floats
        [I0, I90, I45, I135] after background subtraction (aperture photometry).
    gains : iterable of 4 floats or None
        Per-beam scalar corrections (flat/throughput): [g0, g90, g45, g135].
        If None, assumes unity gains.
    q_inst, u_inst : floats
        Instrumental polarization terms to subtract from (Q,U).
    theta0_deg : float
        Additive zero-point of the polarization angle (degrees).
    p_debias : bool
        If True, applies Wardle & Kronberg debias to P.

    Returns
    -------
    Q, U, P, theta_deg : floats
        Normalised Stokes, debiased degree of linear polarization, angle in degrees.
    """

    I0, I90, I45, I135 = map(float, fluxes)

    # Gains (throughput) correction — strongly recommended
    if gains is not None:
        g0, g90, g45, g135 = map(float, gains)
        if min(g0, g90, g45, g135) <= 0 or not np.isfinite([g0,g90,g45,g135]).all():
            raise ValueError("Invalid gains provided.")
        I0   /= g0
        I90  /= g90
        I45  /= g45
        I135 /= g135

    # Sanity checks
    if min(I0, I90, I45, I135) <= 0 or not np.isfinite([I0,I90,I45,I135]).all():
        raise ValueError("Non-positive or non-finite beam flux(es). Check centring, background, flats.")

    denom_Q = I0 + I90
    denom_U = I45 + I135
    if denom_Q <= 0 or denom_U <= 0:
        raise ValueError("Non-positive denominators in Stokes computation.")

    # Stokes (ideal four-channel)
    Q = (I0 - I90) / denom_Q
    U = (I45 - I135) / denom_U

    # Subtract instrumental polarization (measured on unpolarised star)
    Q -= q_inst
    U -= u_inst

    # Rotate by zero-point (convert instrument frame -> celestial frame)
    if theta0_deg != 0.0:
        phi = np.radians(2.0 * theta0_deg)  # note the factor 2 on Stokes space
        Q, U = (Q*np.cos(phi) - U*np.sin(phi),
                Q*np.sin(phi) + U*np.cos(phi))

    # Degree and angle
    P = np.hypot(Q, U)
    theta_deg = 0.5 * np.degrees(np.arctan2(U, Q))

    # Debias (Wardle & Kronberg): P_db = sqrt(P^2 - sigma_P^2), if known
    # If you have per-beam photometric errors, propagate to sigma_Q, sigma_U, hence sigma_P.
    if p_debias:
        # Minimal conservative heuristic (replace with proper error propagation):
        # assume sigma_P ~ max(1/sqrt(I0), ...). Better: compute from aperture variances.
        # Here we avoid negative under the sqrt by clipping:
        sigma_P = 0.0  # <- set your propagated value here
        P = np.sqrt(max(P*P - sigma_P*sigma_P, 0.0))
    # ===============================================================
    # Calcolo incertezze su Q, U e P
    # ===============================================================
    I0_err, I45_err, I90_err, I135_err = np.sqrt(fluxes)
    # Error propagation per Q
    dQ_dI0  =  2 * I90 / (I0 + I90)**2
    dQ_dI90 = -2 * I0  / (I0 + I90)**2
    sigma_Q = np.sqrt((dQ_dI0 * I0_err)**2 + (dQ_dI90 * I90_err)**2)

    # Error propagation per U
    dU_dI45  =  2 * I135 / (I45 + I135)**2
    dU_dI135 = -2 * I45  / (I45 + I135)**2
    sigma_U  = np.sqrt((dU_dI45 * I45_err)**2 + (dU_dI135 * I135_err)**2)

    # Propagazione su P = sqrt(Q² + U²)
    sigma_P = np.sqrt((Q * sigma_Q)**2 + (U * sigma_U)**2) / np.sqrt(Q**2 + U**2)

    # Ritorna tutto insieme
    return Q, U, P, theta_deg, sigma_Q, sigma_U, sigma_P

# ---------------------------------------------------------------------------
# class InteractiveSourceSelector
# ---------------------------------------------------------------------------
# Interactive widget-driven interface built with ipywidgets, managing:
#   - manual source selection for the first image (or when auto-tracking fails),
#   - automated tracking and flux measurement for subsequent images,
#   - on-screen display of images, ROIs, detected sources, and user options.
#
# Key methods:
#   _log(): writes messages to the log panel.
#   _on_dropdown_change(): enables user selection of a detected source.
#   _on_continue_button_click(): triggers photometric measurement after user validation.
#   _derive_all_roi_coords(): computes expected beam positions from one ROI to others.
#   plot_image_with_sources(): displays image, detected sources, and selected targets.
#   _process_current_file(): orchestrates loading, source detection, and measurement per image.
#   _measure_and_save_results(): computes fluxes and Stokes parameters for the selected source.
#   _save_results(): writes the accumulated measurements to an ASCII table.
# The class provides both interactivity and automation for full sequence processing.
# ---------------------------------------------------------------------------
class InteractiveSourceSelector:
    def __init__(self, file_list, roi_origins, roi_w, roi_h, dx, gap, sigma_threshold, npixels, max_move, snr_threshold):
        self.file_list = file_list
        self.roi_origins = roi_origins
        self.roi_w = roi_w
        self.roi_h = roi_h
        self.dx = dx
        self.gap = gap
        self.sigma_threshold = sigma_threshold
        self.npixels = npixels
        self.max_move = max_move
        self.snr_threshold = snr_threshold

        self.current_file_index = 0
        self.prev_selected_coords = np.array([]) # Initialize as empty numpy array
        self.results = []
        self._selected_coords = None
        self._done = False # This flag might become less critical if flow is fully button-driven

        # Widgets
        self.progress_label = widgets.Label(f'Processing file {self.current_file_index + 1}/{len(self.file_list)}: {os.path.basename(self.file_list[self.current_file_index])}')
        self.output_area = widgets.Output() # For plots and dynamic messages
        self.source_dropdown = widgets.Dropdown(description='Select source:', layout=widgets.Layout(width='400px'))
        self.continue_button = widgets.Button(description='CONTINUE', button_style='success', disabled=True)
        self.selected_source_label = widgets.Label('Selected source: None', layout=widgets.Layout(width='150px'))
        self.log_output = widgets.Output(layout={'border': '1px solid black', 'height': '150px', 'overflow_y': 'auto'}) # For log messages

        # Link widgets
        self.source_dropdown.observe(self._on_dropdown_change, names='value')
        self.continue_button.on_click(self._on_continue_button_click)

        # Layout
        self.interface = widgets.VBox([
            self.progress_label,
            self.output_area,
            widgets.HBox([self.source_dropdown, self.continue_button, self.selected_source_label]),
            self.log_output
        ])

    def _log(self, message):
         """Helper to print messages to the log output area."""
         with self.log_output:
             print(message)
    def _as_float(self, x, default=None):
            """Return a Python float if possible, else `default`."""
            try:
                # unwrap numpy scalars/arrays
                if hasattr(x, "value"):  # astropy Quantity
                    x = x.value
                if isinstance(x, (list, tuple, np.ndarray)) and np.size(x) == 1:
                    x = np.asarray(x).reshape(()).item()
                return float(x)
            except Exception:
                return default

    def _as_str(self, x, default=""):
            """Return a clean string (no bytes), stripped; fallback to `default`."""
            try:
                if isinstance(x, bytes):
                    x = x.decode("utf-8", errors="ignore")
                s = str(x).strip()
                return s
            except Exception:
                return default


    def _to_degrees(val):
            try:
                v = float(val)
                return np.degrees(v)
            except Exception:
                return val  # keep as-is if non-numeric


    def _on_dropdown_change(self, change):
        """Enables the continue button when a source is selected."""
        selected_index = change['new']
        if selected_index is not None and hasattr(self, '_current_roi0_sources') and self._current_roi0_sources is not None and selected_index < len(self._current_roi0_sources):
            selected_source = self._current_roi0_sources[selected_index]
            self.selected_source_label.value = f'Selected source: ({selected_source[0]:.1f}, {selected_source[1]:.1f})'
            self.continue_button.disabled = False
        else:
            self.selected_source_label.value = 'Selected source: None'
            self.continue_button.disabled = True

    def _on_continue_button_click(self, b):
        """Handles the button click: processes the current file and proceeds."""
        with self.output_area:
            clear_output(wait=True) # Clear the plot and previous selection interface

        selected_index = self.source_dropdown.value
        if selected_index is not None and hasattr(self, '_current_roi0_sources') and self._current_roi0_sources is not None and selected_index < len(self._current_roi0_sources):
             base_source = self._current_roi0_sources[selected_index]
             selected_coords = self._derive_all_roi_coords(base_source)
             self._selected_coords = selected_coords # Store the selected coords

             # Log the manually selected source ID
             self._log(f"Manually selected source ID: {selected_index}")

             # Proceed to process the current file with the selected coordinates
             if self.current_file_index >= len(self.file_list):
                  self._log("All files processed. Nothing more to measure.")
                  return
             filename = self.file_list[self.current_file_index]

             try:
                 hdul = fits.open(filename)
                 data = hdul[0].data.astype(float)
                 hdul.close()
                 del hdul
                 self._measure_and_save_results(data, selected_coords)
                 gc.collect() # Garbage collection
                 self.prev_selected_coords = selected_coords # Update for next iteration
                 self.current_file_index += 1
                 self._process_current_file() # Process the next file automatically
             except Exception as e:
                 self._log(f"Error processing file after selection {os.path.basename(filename)}: {e}")
                 # Decide how to handle error: skip or require re-selection?
                 # For now, skip and move to next file.
                 self.current_file_index += 1
                 self._process_current_file()
        else:
             self._log("Error: Continue pressed without a valid source selected.")
             # Decide how to handle error: user didn't select or no sources available?
             # For now, skip and move to next file.
             self.current_file_index += 1
             self._process_current_file()

    def _derive_all_roi_coords(self, base_source):
        """Derives the expected coordinates of the source in other ROIs."""
        derived_coords = [base_source]
        for i in range(1, 4):
            rx, ry = self.roi_origins[i]
            if i < 2:
                x_shift = i * self.dx
            else:
                x_shift = i * self.dx + self.gap
            target_x = base_source[0] + x_shift
            target_y = base_source[1]
            derived_coords.append((target_x, target_y))
        return np.array(derived_coords)


    def plot_image_with_sources(self, data_norm, catalog_coords, selected_coords=None):
        """Plots the image, ROIs, detected sources, and optionally selected sources."""
        with self.output_area:
            clear_output(wait=True) # Clear previous plot before displaying new one
            fig, ax = plt.subplots(figsize=(8, 8))
            ax.imshow(data_norm, origin='lower', cmap='gray',
                      vmin=np.percentile(data_norm, 5), vmax=np.percentile(data_norm, 99))
            for i, (rx, ry) in enumerate(self.roi_origins):
                ax.add_patch(patches.Rectangle((rx, ry), self.roi_w, self.roi_h,
                               edgecolor='red', facecolor='none', linewidth=1.5))
                ax.text(rx + 5, ry + self.roi_h - 15, f'ROI {i}', color='red')

            # Plot all sources
            for x, y in catalog_coords:
                ax.plot(x, y, 'o', color='lime', markersize=5)

            # Plot selected sources if available
            if selected_coords is not None and selected_coords.shape == (4, 2):
                 for i, (x, y) in enumerate(selected_coords):
                      ax.plot(x, y, 'X', color='cyan', markersize=10, label=f'Selected (ROI {i})')
                 ax.legend()
            # --- NEW: show aperture and annulus sizes ---
            if selected_coords is not None and hasattr(self, 'results') and len(self.results) > 0:
                last_result = self.results[-1]
                ap_radii = last_result.get('aperture_radii', [])
                ann_radii = last_result.get('annulus_radii', [])
                for i, (x, y) in enumerate(selected_coords):
                    if i < len(ap_radii):
                        circ = patches.Circle((x, y), ap_radii[i], edgecolor='cyan',
                                              facecolor='none', linestyle='--', linewidth=1)
                        ann = patches.Circle((x, y), ann_radii[i], edgecolor='orange',
                                            facecolor='none', linestyle=':', linewidth=1)
                        ax.add_patch(circ)
                        ax.add_patch(ann)
            # Find sources inside ROI 0 (only for manual selection plotting)
            if selected_coords is None:
                rx0, ry0 = self.roi_origins[0]
                roi0_mask = (
                    (catalog_coords[:,0] >= rx0) & (catalog_coords[:,0] <= rx0 + self.roi_w) &
                    (catalog_coords[:,1] >= ry0) & (catalog_coords[:,1] <= ry0 + self.roi_h)
                )
                roi0_sources = catalog_coords[roi0_mask]
                self._current_roi0_sources = roi0_sources # Store for dropdown

                if len(roi0_sources) == 0:
                    self._log("No detected sources inside ROI 0 to select from.")
                    self.source_dropdown.options = []
                    self.continue_button.disabled = True
                else:
                    dropdown_options = [(f"{idx}: x={x:.1f}, y={y:.1f}", idx) for idx, (x, y) in enumerate(roi0_sources)]
                    self.source_dropdown.options = dropdown_options
                    self.source_dropdown.value = None # Reset value to trigger observe if same source is selected again
                    self.continue_button.disabled = True # Disable until a source is selected

                    # Label each source inside ROI 0 with index
                    for idx, (x, y) in enumerate(roi0_sources):
                        ax.text(x+3, y, f"{idx}", color='yellow', fontsize=10, weight='bold')
                ax.set_title("Detected sources with indices inside ROI 0 (Manual Selection)")
            else:
                 ax.set_title("Automatically Selected Sources")


            display(fig) # Display the plot
            plt.close(fig) # Close the figure to prevent duplicate display

    def show(self):
        """Displays the interactive interface."""
        # No need to manage _done flag explicitly for a button-driven flow
        # The display of the interface itself pauses the process until the button is clicked
        display(self.interface)

    def is_done(self):
        """This method is less relevant in a button-driven flow."""
        # Kept for compatibility if needed, but the flow is now controlled by _on_continue_button_click
        return self._done

    def get_selected_coords(self):
        """Returns the selected source coordinates or None."""
        # This is now typically called within the _on_continue_button_click method
        return self._selected_coords

    def update_progress(self, file_index):
        """Updates the progress label."""
        self.current_file_index = file_index
        if self.current_file_index < len(self.file_list):
            self.progress_label.value = f'Processing file {self.current_file_index + 1}/{len(self.file_list)}: {os.path.basename(self.file_list[self.current_file_index])}'
        else:
             self.progress_label.value = 'Processing complete.'


    def run(self):
        """Starts the file processing sequence."""
        # This method initiates the processing of the first file.
        self._process_current_file()

    def _process_current_file(self):
        """Processes the current FITS file, handling automatic or manual selection."""
        from astropy.stats import SigmaClip

        # ===============================================================
        # 🔹 0) Check for completion
        # ===============================================================
        if self.current_file_index >= len(self.file_list):
            self._log("All files processed.")
            self._save_results()
            self.progress_label.value = 'Processing complete.'
            return

        # ===============================================================
        # 🔹 1) Load FITS image
        # ===============================================================
        filename = self.file_list[self.current_file_index]
        self.update_progress(self.current_file_index)
        self._log(f"\nProcessing {os.path.basename(filename)}")

        try:
            with fits.open(filename) as hdul:
                data = hdul[0].data.astype(float)
        except Exception as e:
            self._log(f"[Error] Could not read FITS file {os.path.basename(filename)}: {e}")
            self.current_file_index += 1
            self._process_current_file()  # Skip to next file
            return

        # ===============================================================
        # 🔹 2) Ritaglia la parte superiore (solo regione utile alla polarimetria)
        # ===============================================================
        # Mantieni solo la zona superiore di altezza pari alla ROI (come richiesto)
        data_reduced = data[:self.roi_h, :]

        # ===============================================================
        # 🔹 3) Rimozione del fondo colonnare con media (3σ clipping superiore)
        # ===============================================================
        clipper = SigmaClip(sigma_upper=3.0, sigma_lower=None, maxiters=5)
        data_corrected = data_reduced.copy()


        for col in range(data_corrected.shape[1]):
            col_data = data_corrected[:, col]

            # Considera solo valori finiti e non negativi
            col_valid = col_data[np.isfinite(col_data) & (col_data > 0)]
            if len(col_valid) >= 10:
                clipped = clipper(col_valid)
                sky_mean = np.mean(clipped.data[~clipped.mask])
            elif len(col_valid) > 0:
                sky_mean = np.median(col_valid)
            else:
                sky_mean = 0.0

            # Sottrai il valore medio del cielo per colonna
            data_corrected[:, col] = col_data - sky_mean

        data_reduced = data_corrected
        data = data_reduced
        # ===============================================================
        # 🔹 4) Normalizzazione per il rilevamento
        # ===============================================================
        rx0, ry0 = self.roi_origins[0]
        data_roi0 = data_reduced[ry0:ry0 + self.roi_h, rx0:rx0 + self.roi_w]
        median_roi0 = np.median(data_roi0)
        std_roi0 = np.std(data_roi0)
        data_norm = (data_reduced - median_roi0) / (std_roi0 if std_roi0 > 0 else 1.0)

        # ===============================================================
        # 🔹 5) Rilevamento sorgenti
        # ===============================================================
        catalog_coords = detect_sources_in_image(
            data_norm, self.sigma_threshold, self.npixels,
            self.roi_origins, self.roi_w, self.roi_h
        )

        # Libera memoria intermedia
        del data_corrected
        gc.collect()

        # ===============================================================
        # 🔹 6) Selezione automatica / manuale
        # ===============================================================

        # --- Filtra le sorgenti nella ROI 0
        rx0, ry0 = self.roi_origins[0]
        roi0_mask = (
            (catalog_coords[:, 0] >= rx0) & (catalog_coords[:, 0] <= rx0 + self.roi_w) &
            (catalog_coords[:, 1] >= ry0) & (catalog_coords[:, 1] <= ry0 + self.roi_h)
        )
        roi0_sources = catalog_coords[roi0_mask]

        # --- Caso 1: tracking attivo e sorgente vicina alla posizione precedente
        if (
            self.prev_selected_coords is not None
            and self.prev_selected_coords.shape == (4, 2)
            and len(roi0_sources) > 0
        ):
            prev_x, prev_y = self.prev_selected_coords[0]
            distances = np.sqrt((roi0_sources[:, 0] - prev_x)**2 + (roi0_sources[:, 1] - prev_y)**2)
            close_mask = distances < 25.0
            close_sources = roi0_sources[close_mask]
            if len(close_sources) == 1:
                matched = close_sources[0]
                self._log(f"Source found within 25 px of previous position → auto-selected at "
                          f"({matched[0]:.1f}, {matched[1]:.1f})")

                selected_coords = self._derive_all_roi_coords(matched)
                self._selected_coords = selected_coords
                self._measure_and_save_results(data, selected_coords)
                self.prev_selected_coords = selected_coords
                self.current_file_index += 1
                self._process_current_file()
                del data, catalog_coords
                gc.collect()
                return
            elif len(close_sources) > 1:
                self._log("[WARNING] Multiple sources within 25 px of previous position → switching to manual selection.")

        # --- Caso 2: nessuna sorgente trovata
        if len(roi0_sources) == 0:
            base = os.path.basename(filename)
            self._log(f"[Warning] No sources detected in ROI 0 for {base}. Moving to 'faint_sources' and skipping file.")
            try:
                faint_dir = os.path.join(os.path.dirname(filename), "faint_sources")
                os.makedirs(faint_dir, exist_ok=True)
                dest_path = os.path.join(faint_dir, base)
                if os.path.exists(dest_path):
                    name, ext = os.path.splitext(base)
                    dest_path = os.path.join(faint_dir, f"{name}_dup{ext}")
                shutil.move(filename, dest_path)
                self._log(f"→ File moved to {dest_path}")
            except Exception as move_err:
                self._log(f"[Error] Could not move {base} to faint_sources: {move_err}")
            self.current_file_index += 1
            self._process_current_file()
            return

        # --- Caso 3: singola sorgente → auto-selection
        if len(roi0_sources) == 1:
            single_source = roi0_sources[0]
            print(f"Single source detected, auto-selected at ({single_source[0]:.1f}, {single_source[1]:.1f})")
            selected_coords = self._derive_all_roi_coords(single_source)
            self._selected_coords = selected_coords
            self._measure_and_save_results(data, selected_coords)
            self.prev_selected_coords = selected_coords
            self.current_file_index += 1
            self._process_current_file()
            return

        # --- Caso 4: primo frame o fallimento tracking → selezione manuale
        if (
            self.current_file_index == 0
            or self.prev_selected_coords is None
            or self.prev_selected_coords.shape != (4, 2)
        ):
            if catalog_coords is None or len(catalog_coords) == 0:
                base = os.path.basename(filename)
                self._log(f"[Warning] No sources found for first frame {base}. "
                          "Moving to 'faint_sources' and skipping manual selection.")
                try:
                    faint_dir = os.path.join(os.path.dirname(filename), "faint_sources")
                    os.makedirs(faint_dir, exist_ok=True)
                    dest_path = os.path.join(faint_dir, base)
                    if os.path.exists(dest_path):
                        name, ext = os.path.splitext(base)
                        dest_path = os.path.join(faint_dir, f"{name}_dup{ext}")
                    shutil.move(filename, dest_path)
                    self._log(f"→ File moved to {dest_path}")
                except Exception as move_err:
                    self._log(f"[Error] Could not move {base} to faint_sources: {move_err}")
                gc.collect()
                self.current_file_index += 1
                self._process_current_file()
                return

            self._log("Manual selection required for the first image or due to tracking failure.")
            self.plot_image_with_sources(data_norm, catalog_coords)
            self.show()
            return

        # --- Caso 5: tracking automatico
        selected_coords = match_source_in_new_image(
            self.prev_selected_coords,
            catalog_coords, self.roi_origins,
            self.roi_w, self.roi_h,
            self.dx, self.gap, self.max_move
        )

        if selected_coords is None:
            self._log("Automatic matching failed, switching to manual selection.")
            self.plot_image_with_sources(data_norm, catalog_coords)
            self.show()
        else:
            self._log("Automatic matching successful.")
            self._selected_coords = selected_coords
            self.plot_image_with_sources(data_norm, catalog_coords, selected_coords=selected_coords)

            # Identifica ID sorgente selezionata
            roi0_sources = catalog_coords[roi0_mask]
            if len(roi0_sources) > 0:
                try:
                    match_idx = np.where(
                        np.isclose(roi0_sources, selected_coords[0], atol=0.1).all(axis=1)
                    )[0][0]
                    self._log(f"Automatically selected source ID (in ROI 0 catalog): {match_idx}")
                except IndexError:
                    self._log("Could not determine source ID for automatically selected source.")

            self._measure_and_save_results(data, selected_coords)
            self.prev_selected_coords = selected_coords
            self.current_file_index += 1
            self._process_current_file()

    def _measure_and_save_results(self, data, selected_coords):
        """Measures fluxes and appends results, including FITS metadata."""
        if selected_coords is None or selected_coords.shape != (4, 2):
            self._log("[WARNING] Cannot measure fluxes: invalid or missing selected coordinates.")
            return

        # Recupera nome file corrente
        filename = self.file_list[self.current_file_index]
        # --- Leggi header FITS ---
        with fits.open(filename) as hdul:
            hdr = hdul[0].header

        obj_name = self._as_str(hdr.get("OBJECT", ""))

        rot_angle = hdr.get("ROTANGLE", None)
        rotangle_rad = self._as_float(rot_angle, default=None)

        date_obs_raw = hdr.get("DATE-OBS", "")
        date_obs = self._as_str(date_obs_raw)  # keep ISO-like text

        alt_obs = self._as_float(hdr.get("ALTITUDE", None), default=np.nan)
        azi_obs = self._as_float(hdr.get("AZIMUTH",  None), default=np.nan)

        # EXPTIME robust
        exptime = self._as_float(hdr.get("EXPTIME", None), default=np.nan)

        # FILTER robust
        filt = (hdr.get("FILTER") or hdr.get("FILTER1") or hdr.get("FILT") or "")
        filt = self._as_str(filt)

        if rotangle_rad is not None and np.isfinite(rotangle_rad):
           rotangle_deg = np.degrees(rotangle_rad)
        else:
           rotangle_deg = ""  # empty cell rather than an array or bad string

        # --- Misura i flussi ---
        fluxes, ap_radii, ann_radii, bkg_means, bkg_stds = measure_fluxes_all_rois(
            data, selected_coords, f_threshold=0.01
        )

        if fluxes is None:
            self._log("[WARNING] Skipping image due to failed aperture measurement.")
            return

        I0, I90, I45, I135 = fluxes
        print(f"\nFluxes for {os.path.basename(filename)}:")
        print(f"   I0={I0:.2f}, I90={I90:.2f}, I45={I45:.2f}, I135={I135:.2f}")

        try:
            Q, U, P, theta,sigma_Q,sigma_U,sigma_P, = compute_stokes_dw(fluxes)
            self._log(f"Measured Q={Q:.3f}, U={U:.3f}, P={P:.3f}, theta={theta:.3f}")

            if np.isfinite(exptime) and exptime > 0:
                fluxes_per_sec = (np.array(fluxes, dtype=float) / exptime).tolist()
            else:
                fluxes_per_sec = [np.nan, np.nan, np.nan, np.nan]
            self.results.append({
                'filename': os.path.basename(filename),
                'object':   obj_name,
                'date_obs': date_obs,
                'filter':   filt,
                'rotangle_deg': self._as_float(rotangle_deg, default=np.nan),
                'Q': float(Q), 'U': float(U), 'P': float(P), 'theta': float(theta),
                'fluxes': fluxes_per_sec,
                'azi_obs': azi_obs, 'alt_obs': alt_obs,
                'bkg_means': [float(x) for x in bkg_means],
                'bkg_stds':  [float(x) for x in bkg_stds],
                'aperture_radii': [float(x) for x in ap_radii],
                'annulus_radii':  [float(x) for x in ann_radii],
                'Q_err': float(sigma_Q), 'U_err': float(sigma_U), 'P_err': float(sigma_P),
            })


        except Exception as e:
            self._log(f"Error computing Stokes parameters for {filename}: {e}")

    def _save_results(self):
        """Save all accumulated results to a CSV table."""
        print("saving results")
        if not self.results:
            self._log("No results to save.")
            return

        import csv
        folder_path = os.path.dirname(self.file_list[0])
        out_csv = os.path.join(folder_path, "polarimetry_summary.csv")

        with open(out_csv, "w", newline="") as f:
            writer = csv.writer(f, delimiter=",")
    # Intestazione aggiornata ▼
            writer.writerow([
                "filename", "object", "date_obs", "filter",
                "rotangle_deg", "Q", "U", "P", "theta",
                "Q_err", "U_err", "P_err",
                "I_sum",                 # <--- nuovo campo
                "azimuth", "altitude"
            ])

            for r in self.results:
                # Calcolo sicuro della somma dei flussi, se disponibili
                I_sum = None
                if isinstance(r.get("fluxes", None), (list, tuple)) and len(r["fluxes"]) >= 4:
                    I_sum = sum(r["fluxes"][:4])
                else:
                    I_sum = 0.0

                writer.writerow([
                    r.get("filename", ""),
                    r.get("object", ""),
                    r.get("date_obs", ""),
                    r.get("filter", ""),
                    f"{float(r.get('rotangle_deg', 0)):.6f}" if isinstance(r.get("rotangle_deg", None), (int, float)) else str(r.get("rotangle_deg", "")),
                    f"{r.get('Q', 0):.6f}",
                    f"{r.get('U', 0):.6f}",
                    f"{r.get('P', 0):.6f}",
                    f"{r.get('theta', 0):.3f}",
                    f"{r.get('Q_err', 0):.6f}",
                    f"{r.get('U_err', 0):.6f}",
                    f"{r.get('P_err', 0):.6f}",
                    f"{I_sum:.3f}",         # <--- somma dei flussi
                    f"{r.get('azi_obs', 0):.3f}",
                    f"{r.get('alt_obs', 0):.3f}",
                ])
            self._log(f"\nSummary CSV saved to {out_csv}")

# ---------------------------------------------------------------------------
# process_all_files_with_interface
# ---------------------------------------------------------------------------
# Main entry point to execute the full polarimetric reduction pipeline.
# Scans a specified directory for FITS files, instantiates the interactive
# selector class, and initiates the iterative processing of all images.
# The workflow alternates between automatic and manual selection depending
# on the tracking success, ultimately generating a table of Stokes parameters
# and polarization angles for all frames in the sequence.
# ---------------------------------------------------------------------------
def process_all_files_with_interface(folder_path, roi_origins, roi_w, roi_h,
                                     dx, gap, sigma_threshold, npixels,
                                     max_move, snr_threshold):
    """
    Scansiona la cartella indicata, elabora tutti i file FITS e FITS.GZ,
    e avvia l'interfaccia interattiva per la selezione delle sorgenti.
    """

    # --- 1️⃣ Raccoglie i file presenti nella cartella ---
    all_files = os.listdir(folder_path)
    file_list = sorted([
        os.path.join(folder_path, f)
        for f in all_files
        if f.lower().endswith(".fits") or f.lower().endswith(".fits.gz")
    ])

    # --- 2️⃣ Controllo dei file trovati ---
    if not file_list:
        print(f"No FITS or FITS.GZ files found in {folder_path}")
        return

    print(f"Found {len(file_list)} FITS/FITS.GZ files to process:")
    for f in file_list[:10]:  # stampa solo i primi 10 per non saturare l’output
        print("  ", os.path.basename(f))
    if len(file_list) > 10:
        print(f"  ... and {len(file_list) - 10} more files.\n")

    '''# --- 3️⃣ Avvia l'interfaccia interattiva ---
    try:
        selector = InteractiveSourceSelector(
            file_list, roi_origins, roi_w, roi_h,
            dx, gap, sigma_threshold, npixels, max_move, snr_threshold
        )
        selector.show()
    except Exception as e:
        print(f"Error launching interactive processing: {e}")'''

    # Instantiate the selector with all necessary parameters
    selector = InteractiveSourceSelector(
        file_list, roi_origins, roi_w, roi_h,
        dx, gap,  sigma_threshold, npixels, max_move, snr_threshold
    )
    # Run the selector; it will manage the file processing and interaction flow
    selector.run()

# --- Cell S1z2OfQfWQrj (parameters and call) needs to be updated to call the non-async function ---
# Assuming the parameter definitions exist from cell S1z2OfQfWQrj
# sigma_threshold, npixels, roi_w, roi_h, roi0_x, roi0_y, dx, gap, roi_origins, max_move, snr_threshold, folder_path
# are assumed to be defined before calling this function.

# Example call (would be in a separate cell, e.g., the modified S1z2OfQfWQrj)
# process_all_files_with_interface(folder_path, roi_origins, roi_w, roi_h, dx, gap, sigma_threshold, npixels, max_move, snr_threshold)

# Note: The interactive interface will be displayed inline when selector.show() is called.
# The flow pauses at that point until the user clicks the 'CONTINUE' button.
# The processing of the next file is triggered by the button click handler.

# %%
import shutil
from astropy.io import fits
import os
import glob
import numpy as np

# HOTBIRD 13 F
input_folder = "/content/drive/Shared drives/Emissary/OSSERVAZIONI_EKAR/20251025/HOTBIRD_13F_PL"
#input_folder = "/content/drive/Shared drives/Emissary/OSSERVAZIONI_EKAR/20251025/HOTBIRD"

# UNPOLARIZED STAR
input_folder = "/content/drive/Shared drives/Emissary/OSSERVAZIONI_EKAR/20251026/HD39587"

# POLARIZED STAR
input_folder = "/content/drive/Shared drives/Emissary/OSSERVAZIONI_EKAR/20251027/HD283809"

# POLARIZED STAR
input_folder = "/content/drive/Shared drives/Emissary/OSSERVAZIONI_EKAR/20251028/POL_STARS2"

input_folder = "/content/drive/Shared drives/Emissary/OSSERVAZIONI_EKAR/20251028/POL_STARS"

# UNPOLARIZED STAR
input_folder = "/content/drive/Shared drives/Emissary/OSSERVAZIONI_EKAR/20251028/HD42182_1st"
#input_folder = "/content/drive/Shared drives/Emissary/OSSERVAZIONI_EKAR/20251028/HD42182_2nd"
#input_folder = "/content/drive/Shared drives/Emissary/OSSERVAZIONI_EKAR/20251028/HD42182_Test"





output_folder = input_folder + "/non_pol"

os.makedirs(output_folder, exist_ok=True)
for filename in os.listdir(input_folder):
    # accetta estensioni .fits oppure .fits.gz
    lower = filename.lower()
    if not (lower.endswith(".fits") or lower.endswith(".fits.gz")):
        continue

    filepath = os.path.join(input_folder, filename)

    with fits.open(filepath) as hdul:
        hdr = hdul[0].header

        grat = hdr.get("GRAT_TYP", None)
        obj = hdr.get("OBJECT", "N/A")
        exptime = hdr.get("EXPTIME", "N/A")
        filt = hdr.get("FILTER", "N/A")
        rotangle = hdr.get("ROTANGLE", "N/A")
        date_obs = hdr.get("DATE-OBS", "N/A")
        alt_obs = hdr.get("ALTITUDE", "N/A")
        azi_obs = hdr.get("AZIMUTH", "N/A")
        hdul.close()
        del hdul
        gc.collect()


        if isinstance(rotangle, (int, float)):
            rotangle_deg = np.degrees(rotangle)
            rotangle_str = f"{rotangle_deg:.1f}"
        else:
            rotangle_str = str(rotangle)

        if grat != "Pol":
            print(f"Moving {filename} (Object: {obj}, Exptime: {exptime}, Filter: {filt}, RotAngle: {rotangle_str} deg, Date-Obs: {date_obs}) to {output_folder}")
            shutil.move(filepath, os.path.join(output_folder, filename))
        else:
            print(f"Keeping {filename} (Object: {obj}, Exptime: {exptime}, Filter: {filt}, RotAngle: {rotangle_str} deg, Date-Obs: {date_obs})")
# Out:
# Keeping AF969610.fits.gz (Object: HD42182, Exptime: 1.0, Filter: r-Sloan, RotAngle: -0.0 deg, Date-Obs: 2025-10-29T01:09:43.9)
# Keeping AF969611.fits.gz (Object: HD42182, Exptime: 1.0, Filter: V-Bessel, RotAngle: -0.0 deg, Date-Obs: 2025-10-29T01:10:32.7)
# Keeping AF969612.fits.gz (Object: HD42182, Exptime: 1.0, Filter: NONE, RotAngle: -0.0 deg, Date-Obs: 2025-10-29T01:11:10.5)
# Keeping AF969614.fits.gz (Object: HD42182, Exptime: 3.0, Filter: i-Sloan, RotAngle: -0.0 deg, Date-Obs: 2025-10-29T01:12:30.3)
# Keeping AF969613.fits.gz (Object: HD42182, Exptime: 10.0, Filter: B-Bessel, RotAngle: -0.0 deg, Date-Obs: 2025-10-29T01:11:44.0)
# Keeping AF969615.fits.gz (Object: HD42182, Exptime: 1.0, Filter: r-Sloan, RotAngle: -0.0 deg, Date-Obs: 2025-10-29T01:13:53.5)
# Keeping AF969616.fits.gz (Object: HD42182, Exptime: 1.0, Filter: r-Sloan, RotAngle: -0.0 deg, Date-Obs: 2025-10-29T01:14:00.9)
# Keeping AF969617.fits.gz (Object: HD42182, Exptime: 1.0, Filter: r-Sloan, RotAngle: -0.0 deg, Date-Obs: 2025-10-29T01:14:08.3)
# Keeping AF969618.fits.gz (Object: HD42182, Exptime: 1.0, Filter: r-Sloan, RotAngle: -0.0 deg, Date-Obs: 2025-10-29T01:14:15.8)
# Keeping AF969619.fits.gz (Object: HD42182, Exptime: 1.0, Filter: r-Sloan, RotAngle: -0.0 deg, Date-Obs: 2025-10-29T01:14:23.2)
# Keeping AF969620.fits.gz (Object: HD42182, Exptime: 1.0, Filter: r-Sloan, RotAngle: -0.0 deg, Date-Obs: 2025-10-29T01:14:30.7)
# Keeping AF969621.fits.gz (Object: HD42182, Exptime: 1.0, Filter: r-Sloan, RotAngle: -0.0 deg, Date-Obs: 2025-10-29T01:14:39.2)
# Keeping AF969622.fits.gz (Object: HD42182, Exptime: 1.0, Filter: r-Sloan, RotAngle: -0.0 deg, Date-Obs: 2025-10-29T01:14:46.7)
# Keeping AF969623.fits.gz (Object: HD42182, Exptime: 1.0, Filter: r-Sloan, RotAngle: -0.0 deg, Date-Obs: 2025-10-29T01:14:54.1)
# Keeping AF969624.fits.gz (Object: HD42182, Exptime: 1.0, Filter: r-Sloan, RotAngle: -0.0 deg, Date-Obs: 2025-10-29T01:15:01.6)
# Keeping AF969625.fits.gz (Object: HD42182, Exptime: 3.0, Filter: V-Bessel, RotAngle: -0.0 deg, Date-Obs: 2025-10-29T01:15:19.3)
# Keeping AF969626.fits.gz (Object: HD42182, Exptime: 3.0, Filter: V-Bessel, RotAngle: -0.0 deg, Date-Obs: 2025-10-29T01:15:28.8)
# Keeping AF969627.fits.gz (Object: HD42182, Exptime: 3.0, Filter: V-Bessel, RotAngle: -0.0 deg, Date-Obs: 2025-10-29T01:15:38.2)
# Keeping AF969628.fits.gz (Object: HD42182, Exptime: 3.0, Filter: V-Bessel, RotAngle: -0.0 deg, Date-Obs: 2025-10-29T01:15:47.9)
# Keeping AF969630.fits.gz (Object: HD42182, Exptime: 3.0, Filter: V-Bessel, RotAngle: -0.0 deg, Date-Obs: 2025-10-29T01:16:06.9)
# Keeping AF969629.fits.gz (Object: HD42182, Exptime: 3.0, Filter: V-Bessel, RotAngle: -0.0 deg, Date-Obs: 2025-10-29T01:15:57.4)
# Keeping AF969631.fits.gz (Object: HD42182, Exptime: 3.0, Filter: V-Bessel, RotAngle: -0.0 deg, Date-Obs: 2025-10-29T01:16:16.3)
# Keeping AF969632.fits.gz (Object: HD42182, Exptime: 3.0, Filter: V-Bessel, RotAngle: -0.0 deg, Date-Obs: 2025-10-29T01:16:25.8)
# Keeping AF969634.fits.gz (Object: HD42182, Exptime: 3.0, Filter: V-Bessel, RotAngle: -0.0 deg, Date-Obs: 2025-10-29T01:16:44.7)
# Keeping AF969633.fits.gz (Object: HD42182, Exptime: 3.0, Filter: V-Bessel, RotAngle: -0.0 deg, Date-Obs: 2025-10-29T01:16:35.3)
# Keeping AF969635.fits.gz (Object: HD42182, Exptime: 30.0, Filter: B-Bessel, RotAngle: -0.0 deg, Date-Obs: 2025-10-29T01:17:01.4)
# Keeping AF969636.fits.gz (Object: HD42182, Exptime: 30.0, Filter: B-Bessel, RotAngle: -0.0 deg, Date-Obs: 2025-10-29T01:17:37.7)
# Keeping AF969638.fits.gz (Object: HD42182, Exptime: 30.0, Filter: B-Bessel, RotAngle: -0.0 deg, Date-Obs: 2025-10-29T01:18:50.7)
# Keeping AF969637.fits.gz (Object: HD42182, Exptime: 30.0, Filter: B-Bessel, RotAngle: -0.0 deg, Date-Obs: 2025-10-29T01:18:14.2)
# Keeping AF969639.fits.gz (Object: HD42182, Exptime: 30.0, Filter: B-Bessel, RotAngle: -0.0 deg, Date-Obs: 2025-10-29T01:19:27.1)
# Keeping AF969641.fits.gz (Object: HD42182, Exptime: 30.0, Filter: B-Bessel, RotAngle: -0.0 deg, Date-Obs: 2025-10-29T01:20:40.0)
# Keeping AF969640.fits.gz (Object: HD42182, Exptime: 30.0, Filter: B-Bessel, RotAngle: -0.0 deg, Date-Obs: 2025-10-29T01:20:03.5)
# Keeping AF969642.fits.gz (Object: HD42182, Exptime: 30.0, Filter: B-Bessel, RotAngle: -0.0 deg, Date-Obs: 2025-10-29T01:21:16.7)
# Keeping AF969643.fits.gz (Object: HD42182, Exptime: 30.0, Filter: B-Bessel, RotAngle: -0.0 deg, Date-Obs: 2025-10-29T01:21:53.1)
# Keeping AF969644.fits.gz (Object: HD42182, Exptime: 30.0, Filter: B-Bessel, RotAngle: -0.0 deg, Date-Obs: 2025-10-29T01:22:29.6)
# Keeping AF969645.fits.gz (Object: HD42182, Exptime: 2.0, Filter: i-Sloan, RotAngle: -0.0 deg, Date-Obs: 2025-10-29T01:23:23.3)
# Keeping AF969646.fits.gz (Object: HD42182, Exptime: 2.0, Filter: i-Sloan, RotAngle: -0.0 deg, Date-Obs: 2025-10-29T01:23:31.8)
# Keeping AF969647.fits.gz (Object: HD42182, Exptime: 2.0, Filter: i-Sloan, RotAngle: -0.0 deg, Date-Obs: 2025-10-29T01:23:40.2)
# Keeping AF969648.fits.gz (Object: HD42182, Exptime: 2.0, Filter: i-Sloan, RotAngle: -0.0 deg, Date-Obs: 2025-10-29T01:23:48.7)
# Keeping AF969649.fits.gz (Object: HD42182, Exptime: 2.0, Filter: i-Sloan, RotAngle: -0.0 deg, Date-Obs: 2025-10-29T01:23:57.1)
# Keeping AF969651.fits.gz (Object: HD42182, Exptime: 2.0, Filter: i-Sloan, RotAngle: -0.0 deg, Date-Obs: 2025-10-29T01:24:14.0)
# Keeping AF969650.fits.gz (Object: HD42182, Exptime: 2.0, Filter: i-Sloan, RotAngle: -0.0 deg, Date-Obs: 2025-10-29T01:24:05.6)
# Keeping AF969652.fits.gz (Object: HD42182, Exptime: 2.0, Filter: i-Sloan, RotAngle: -0.0 deg, Date-Obs: 2025-10-29T01:24:22.7)
# Keeping AF969653.fits.gz (Object: HD42182, Exptime: 2.0, Filter: i-Sloan, RotAngle: -0.0 deg, Date-Obs: 2025-10-29T01:24:31.1)
# Keeping AF969655.fits.gz (Object: HD42182, Exptime: 1.0, Filter: i-Sloan, RotAngle: -0.0 deg, Date-Obs: 2025-10-29T01:26:04.5)
# Keeping AF969654.fits.gz (Object: HD42182, Exptime: 2.0, Filter: i-Sloan, RotAngle: -0.0 deg, Date-Obs: 2025-10-29T01:24:39.5)
# Keeping AF969656.fits.gz (Object: HD42182, Exptime: 1.0, Filter: i-Sloan, RotAngle: -0.0 deg, Date-Obs: 2025-10-29T01:26:11.9)
# Keeping AF969657.fits.gz (Object: HD42182, Exptime: 1.0, Filter: i-Sloan, RotAngle: -0.0 deg, Date-Obs: 2025-10-29T01:26:19.8)
# Keeping AF969658.fits.gz (Object: HD42182, Exptime: 1.0, Filter: i-Sloan, RotAngle: -0.0 deg, Date-Obs: 2025-10-29T01:26:27.1)
# Keeping AF969659.fits.gz (Object: HD42182, Exptime: 1.0, Filter: i-Sloan, RotAngle: -0.0 deg, Date-Obs: 2025-10-29T01:26:34.6)
# Keeping AF969660.fits.gz (Object: HD42182, Exptime: 1.0, Filter: i-Sloan, RotAngle: -0.0 deg, Date-Obs: 2025-10-29T01:26:42.1)
# Keeping AF969661.fits.gz (Object: HD42182, Exptime: 1.0, Filter: i-Sloan, RotAngle: -0.0 deg, Date-Obs: 2025-10-29T01:26:49.9)
# Keeping AF969662.fits.gz (Object: HD42182, Exptime: 1.0, Filter: i-Sloan, RotAngle: -0.0 deg, Date-Obs: 2025-10-29T01:26:57.3)
# Keeping AF969663.fits.gz (Object: HD42182, Exptime: 1.0, Filter: i-Sloan, RotAngle: -0.0 deg, Date-Obs: 2025-10-29T01:27:04.7)
# Keeping AF969664.fits.gz (Object: HD42182, Exptime: 1.0, Filter: i-Sloan, RotAngle: -0.0 deg, Date-Obs: 2025-10-29T01:27:12.4)
# Keeping AF969676.fits.gz (Object: HD42182, Exptime: 1.0, Filter: r-Sloan, RotAngle: 45.8 deg, Date-Obs: 2025-10-29T01:35:21.3)
# Keeping AF969677.fits.gz (Object: HD42182, Exptime: 1.0, Filter: r-Sloan, RotAngle: 45.8 deg, Date-Obs: 2025-10-29T01:35:30.9)
# Keeping AF969678.fits.gz (Object: HD42182, Exptime: 1.0, Filter: r-Sloan, RotAngle: 45.8 deg, Date-Obs: 2025-10-29T01:35:54.3)
# Keeping AF969679.fits.gz (Object: HD42182, Exptime: 1.0, Filter: r-Sloan, RotAngle: 45.8 deg, Date-Obs: 2025-10-29T01:36:42.0)
# Keeping AF969680.fits.gz (Object: HD42182, Exptime: 1.0, Filter: r-Sloan, RotAngle: 45.8 deg, Date-Obs: 2025-10-29T01:36:49.4)
# Keeping AF969681.fits.gz (Object: HD42182, Exptime: 1.0, Filter: r-Sloan, RotAngle: 45.8 deg, Date-Obs: 2025-10-29T01:36:56.8)
# Keeping AF969682.fits.gz (Object: HD42182, Exptime: 1.0, Filter: r-Sloan, RotAngle: 45.8 deg, Date-Obs: 2025-10-29T01:37:04.7)
# Keeping AF969683.fits.gz (Object: HD42182, Exptime: 1.0, Filter: r-Sloan, RotAngle: 45.8 deg, Date-Obs: 2025-10-29T01:37:12.1)
# Keeping AF969684.fits.gz (Object: HD42182, Exptime: 1.0, Filter: r-Sloan, RotAngle: 45.8 deg, Date-Obs: 2025-10-29T01:37:20.8)
# Keeping AF969685.fits.gz (Object: HD42182, Exptime: 1.0, Filter: r-Sloan, RotAngle: 45.8 deg, Date-Obs: 2025-10-29T01:37:28.2)
# Keeping AF969686.fits.gz (Object: HD42182, Exptime: 1.0, Filter: r-Sloan, RotAngle: 45.8 deg, Date-Obs: 2025-10-29T01:37:36.1)
# Keeping AF969687.fits.gz (Object: HD42182, Exptime: 1.0, Filter: r-Sloan, RotAngle: 45.8 deg, Date-Obs: 2025-10-29T01:37:43.7)
# Keeping AF969688.fits.gz (Object: HD42182, Exptime: 1.0, Filter: r-Sloan, RotAngle: 45.8 deg, Date-Obs: 2025-10-29T01:37:51.1)
# Keeping AF969690.fits.gz (Object: HD42182, Exptime: 3.0, Filter: V-Bessel, RotAngle: 45.8 deg, Date-Obs: 2025-10-29T01:38:18.7)
# Keeping AF969689.fits.gz (Object: HD42182, Exptime: 3.0, Filter: V-Bessel, RotAngle: 45.8 deg, Date-Obs: 2025-10-29T01:38:08.9)
# Keeping AF969691.fits.gz (Object: HD42182, Exptime: 3.0, Filter: V-Bessel, RotAngle: 45.8 deg, Date-Obs: 2025-10-29T01:38:28.1)
# Keeping AF969692.fits.gz (Object: HD42182, Exptime: 3.0, Filter: V-Bessel, RotAngle: 45.8 deg, Date-Obs: 2025-10-29T01:38:37.5)
# Keeping AF969694.fits.gz (Object: HD42182, Exptime: 3.0, Filter: V-Bessel, RotAngle: 45.8 deg, Date-Obs: 2025-10-29T01:38:56.3)
# Keeping AF969693.fits.gz (Object: HD42182, Exptime: 3.0, Filter: V-Bessel, RotAngle: 45.8 deg, Date-Obs: 2025-10-29T01:38:46.9)
# Keeping AF969695.fits.gz (Object: HD42182, Exptime: 3.0, Filter: V-Bessel, RotAngle: 45.8 deg, Date-Obs: 2025-10-29T01:39:05.8)
# Keeping AF969696.fits.gz (Object: HD42182, Exptime: 3.0, Filter: V-Bessel, RotAngle: 45.8 deg, Date-Obs: 2025-10-29T01:39:15.2)
# Keeping AF969697.fits.gz (Object: HD42182, Exptime: 3.0, Filter: V-Bessel, RotAngle: 45.8 deg, Date-Obs: 2025-10-29T01:39:24.7)
# Keeping AF969698.fits.gz (Object: HD42182, Exptime: 3.0, Filter: V-Bessel, RotAngle: 45.8 deg, Date-Obs: 2025-10-29T01:39:34.1)
# Keeping AF969699.fits.gz (Object: HD42182, Exptime: 30.0, Filter: B-Bessel, RotAngle: 45.8 deg, Date-Obs: 2025-10-29T01:39:50.8)
# Keeping AF969700.fits.gz (Object: HD42182, Exptime: 30.0, Filter: B-Bessel, RotAngle: 45.8 deg, Date-Obs: 2025-10-29T01:40:27.2)
# Keeping AF969701.fits.gz (Object: HD42182, Exptime: 30.0, Filter: B-Bessel, RotAngle: 45.8 deg, Date-Obs: 2025-10-29T01:41:03.7)
# Keeping AF969702.fits.gz (Object: HD42182, Exptime: 30.0, Filter: B-Bessel, RotAngle: 45.8 deg, Date-Obs: 2025-10-29T01:41:40.1)
# Keeping AF969703.fits.gz (Object: HD42182, Exptime: 30.0, Filter: B-Bessel, RotAngle: 45.8 deg, Date-Obs: 2025-10-29T01:42:16.8)
# Keeping AF969704.fits.gz (Object: HD42182, Exptime: 30.0, Filter: B-Bessel, RotAngle: 45.8 deg, Date-Obs: 2025-10-29T01:42:53.3)
# Keeping AF969705.fits.gz (Object: HD42182, Exptime: 30.0, Filter: B-Bessel, RotAngle: 45.8 deg, Date-Obs: 2025-10-29T01:43:29.7)
# Keeping AF969706.fits.gz (Object: HD42182, Exptime: 30.0, Filter: B-Bessel, RotAngle: 45.8 deg, Date-Obs: 2025-10-29T01:44:06.1)
# Keeping AF969707.fits.gz (Object: HD42182, Exptime: 30.0, Filter: B-Bessel, RotAngle: 45.8 deg, Date-Obs: 2025-10-29T01:44:42.7)
# Keeping AF969708.fits.gz (Object: HD42182, Exptime: 30.0, Filter: B-Bessel, RotAngle: 45.8 deg, Date-Obs: 2025-10-29T01:45:19.1)
# Keeping AF969709.fits.gz (Object: HD42182, Exptime: 1.0, Filter: i-Sloan, RotAngle: 45.8 deg, Date-Obs: 2025-10-29T01:46:12.7)
# Keeping AF969710.fits.gz (Object: HD42182, Exptime: 1.0, Filter: i-Sloan, RotAngle: 45.8 deg, Date-Obs: 2025-10-29T01:46:20.1)
# Keeping AF969711.fits.gz (Object: HD42182, Exptime: 1.0, Filter: i-Sloan, RotAngle: 45.8 deg, Date-Obs: 2025-10-29T01:46:27.6)
# Keeping AF969712.fits.gz (Object: HD42182, Exptime: 1.0, Filter: i-Sloan, RotAngle: 45.8 deg, Date-Obs: 2025-10-29T01:46:35.1)
# Keeping AF969713.fits.gz (Object: HD42182, Exptime: 1.0, Filter: i-Sloan, RotAngle: 45.8 deg, Date-Obs: 2025-10-29T01:46:42.7)
# Keeping AF969714.fits.gz (Object: HD42182, Exptime: 1.0, Filter: i-Sloan, RotAngle: 45.8 deg, Date-Obs: 2025-10-29T01:46:50.4)
# Keeping AF969715.fits.gz (Object: HD42182, Exptime: 1.0, Filter: i-Sloan, RotAngle: 45.8 deg, Date-Obs: 2025-10-29T01:46:58.6)
# Keeping AF969716.fits.gz (Object: HD42182, Exptime: 1.0, Filter: i-Sloan, RotAngle: 45.8 deg, Date-Obs: 2025-10-29T01:47:06.0)
# Keeping AF969717.fits.gz (Object: HD42182, Exptime: 1.0, Filter: i-Sloan, RotAngle: 45.8 deg, Date-Obs: 2025-10-29T01:47:13.5)
# Keeping AF969719.fits.gz (Object: HD42182, Exptime: 1.0, Filter: r-Sloan, RotAngle: 45.8 deg, Date-Obs: 2025-10-29T01:47:35.5)
# Keeping AF969718.fits.gz (Object: HD42182, Exptime: 1.0, Filter: i-Sloan, RotAngle: 45.8 deg, Date-Obs: 2025-10-29T01:47:20.9)
# Keeping AF969720.fits.gz (Object: HD42182, Exptime: 1.0, Filter: r-Sloan, RotAngle: 45.8 deg, Date-Obs: 2025-10-29T01:47:43.0)
# Keeping AF969721.fits.gz (Object: HD42182, Exptime: 1.0, Filter: r-Sloan, RotAngle: 45.8 deg, Date-Obs: 2025-10-29T01:47:50.4)
# Keeping AF969722.fits.gz (Object: HD42182, Exptime: 1.0, Filter: r-Sloan, RotAngle: 45.8 deg, Date-Obs: 2025-10-29T01:47:57.8)
# Keeping AF969723.fits.gz (Object: HD42182, Exptime: 1.0, Filter: r-Sloan, RotAngle: 45.8 deg, Date-Obs: 2025-10-29T01:48:05.3)
# Keeping AF969724.fits.gz (Object: HD42182, Exptime: 1.0, Filter: r-Sloan, RotAngle: 45.8 deg, Date-Obs: 2025-10-29T01:48:12.7)
# Keeping AF969725.fits.gz (Object: HD42182, Exptime: 1.0, Filter: r-Sloan, RotAngle: 45.8 deg, Date-Obs: 2025-10-29T01:48:20.2)
# Keeping AF969726.fits.gz (Object: HD42182, Exptime: 1.0, Filter: r-Sloan, RotAngle: 45.8 deg, Date-Obs: 2025-10-29T01:48:27.8)
# Keeping AF969727.fits.gz (Object: HD42182, Exptime: 1.0, Filter: r-Sloan, RotAngle: 45.8 deg, Date-Obs: 2025-10-29T01:48:35.2)
# Keeping AF969728.fits.gz (Object: HD42182, Exptime: 1.0, Filter: r-Sloan, RotAngle: 45.8 deg, Date-Obs: 2025-10-29T01:48:42.8)
# Keeping AF969729.fits.gz (Object: HD42182, Exptime: 3.0, Filter: V-Bessel, RotAngle: 45.8 deg, Date-Obs: 2025-10-29T01:49:00.4)
# Keeping AF969730.fits.gz (Object: HD42182, Exptime: 3.0, Filter: V-Bessel, RotAngle: 45.8 deg, Date-Obs: 2025-10-29T01:49:09.8)

# %%
# === PARAMETERS ===
sigma_threshold = 3.0
npixels = 5
max_move = 5   # max px for automatic source tracking between images
snr_threshold = 2  # for aperture radius selection
#####################

folder_path = input_folder  # esempio: "/content/.../HD283809"

# --- 1️⃣ Elenco dei file nella directory ---
all_files = os.listdir(folder_path)
file_list = sorted([
    os.path.join(folder_path, f)
    for f in all_files
    if f.lower().endswith(".fits") or f.lower().endswith(".fits.gz")
])

# --- 2️⃣ Controllo ---
if not file_list:
    print(f"[Warning] No FITS or FITS.GZ files found in {folder_path}")
else:
    n_files = len(file_list)
    print(f"[INFO] Found {n_files} FITS/FITS.GZ files in {folder_path}")

    # mostra solo i primi 10 file, per evitare output lunghissimo
    for f in file_list[:10]:
        print("   ", os.path.basename(f))
    if n_files > 10:
        print(f"   ... and {n_files - 10} more files not shown.\n")


    # --- 3️⃣ Leggi il primo file per determinare il binning ---
    try:
        first_file = file_list[0]
        print(f"\nReading header from: {os.path.basename(first_file)}")

        with fits.open(first_file) as hdul:
            hdr = hdul[0].header
            binx = hdr.get("BINX", 1)
            biny = hdr.get("BINY", 1)
        del hdul
        gc.collect()

        print(f"Binning detected: {binx}x{biny}")

        # --- 4️⃣ Parametri per ROI a seconda del binning ---
        if binx == 2 and biny == 2:
            roi_w, roi_h = 50, 936
            roi0_x, roi0_y = 404, 0
            dx = 60
            gap = -5
        elif binx == 1 and biny == 1:
            roi_w, roi_h = 100, 1872
            roi0_x, roi0_y = 808, 0
            dx = 120
            gap = -8
        else:
            print(f"[WARNING] Unsupported binning {binx}x{biny}. Using default parameters.")
            roi_w, roi_h = 50, 936
            roi0_x, roi0_y = 404, 0
            dx = 60
            gap = -4

        roi_origins = [
            (roi0_x, roi0_y),
            (roi0_x + dx, roi0_y),
            (roi0_x + 2 * dx + gap, roi0_y),
            (roi0_x + 3 * dx + gap, roi0_y),
        ]

        # --- 5️⃣ Esegui la pipeline ---
        process_all_files_with_interface(
            folder_path, roi_origins, roi_w, roi_h,
            dx, gap, sigma_threshold, npixels,
            max_move, snr_threshold
        )

    except Exception as e:
        print(f"Error reading FITS header or processing files: {e}")


# Note: The interactive interface will be displayed inline when selector.show() is called.
# The flow pauses at that point until the user clicks the 'CONTINUE' button.
# The processing of the next file is triggered by the button click handler.
# Out:
# [INFO] Found 110 FITS/FITS.GZ files in /content/drive/Shared drives/Emissary/OSSERVAZIONI_EKAR/20251028/HD42182_1st
#     AF969610.fits.gz
#     AF969611.fits.gz
#     AF969612.fits.gz
#     AF969613.fits.gz
#     AF969614.fits.gz
#     AF969615.fits.gz
#     AF969616.fits.gz
#     AF969617.fits.gz
#     AF969618.fits.gz
#     AF969619.fits.gz
#    ... and 100 more files not shown.
#
#
# Reading header from: AF969610.fits.gz
# Binning detected: 1x1
# Found 110 FITS/FITS.GZ files to process:
#    AF969610.fits.gz
#    AF969611.fits.gz
#    AF969612.fits.gz
#    AF969613.fits.gz
#    AF969614.fits.gz
#    AF969615.fits.gz
#    AF969616.fits.gz
#    AF969617.fits.gz
#    AF969618.fits.gz
#    AF969619.fits.gz
#   ... and 100 more files.
#
# [Info] Detected 5 sources in defined ROIs.
#   ROI 1: x = 967.09, y = 929.02
#   ROI 2: x = 859.24, y = 930.10
#   ROI 3: x = 1202.12, y = 930.43
#   ROI 4: x = 1094.31, y = 931.24
#   ROI 5: x = 845.23, y = 1865.06
# VBox(children=(Label(value='Processing file 1/110: AF969610.fits.gz'), Output(), HBox(children=(Dropdown(descr…
# ROI 0 initial (859.2,930.1) → refined (858.8,929.9)
# [DEBUG] In iterative: median=1260.00, min=1242.00, max=24603.00
# ROI 1 initial (979.2,930.1) → refined (978.5,927.8)
# [DEBUG] In iterative: median=1260.00, min=1242.00, max=24603.00
# ROI 2 initial (1091.2,930.1) → refined (1091.4,931.4)
# [DEBUG] In iterative: median=1260.00, min=1242.00, max=24603.00
# ROI 3 initial (1211.2,930.1) → refined (1210.9,926.2)
# [DEBUG] In iterative: median=1260.00, min=1242.00, max=24603.00
# [Info] Negative flux (-330.43) at r=2.0 for (1210.9,926.2); continuing. phot_table 17800.47, bkg_mean 1442.81, aperture.area 12.57)
# [INFO] Using common aperture radius = 21.00 px, annulus outer radius = 28.00 px, minimum radii was 14.00
# ROI 0: flux=557076.7, Bkg=1264.43, RMS=4.37
# ROI 1: flux=550928.1, Bkg=1266.21, RMS=4.94
# ROI 2: flux=622267.2, Bkg=1264.79, RMS=4.06
# ROI 3: flux=624818.4, Bkg=1266.85, RMS=5.40
#
# Fluxes for AF969610.fits.gz:
#    I0=557076.73, I90=550928.08, I45=622267.17, I135=624818.39
# [Info] Detected 4 sources in defined ROIs.
#   ROI 1: x = 962.69, y = 935.22
#   ROI 2: x = 853.90, y = 936.34
#   ROI 3: x = 1198.54, y = 937.23
#   ROI 4: x = 1089.79, y = 938.07
# ROI 0 initial (853.9,936.3) → refined (854.3,935.9)
# [DEBUG] In iterative: median=0.15, min=-18.65, max=9897.21
# ROI 1 initial (973.9,936.3) → refined (973.4,928.3)
# [DEBUG] In iterative: median=0.15, min=-18.65, max=9897.21
# [Info] Negative flux (-85.62) at r=2.0 for (973.4,928.3); continuing. phot_table 471.74, bkg_mean 44.35, aperture.area 12.57)
# [Info] Negative flux (-281.97) at r=3.0 for (973.4,928.3); continuing. phot_table 1103.11, bkg_mean 48.99, aperture.area 28.27)
# [Info] Negative flux (-103.62) at r=4.0 for (973.4,928.3); continuing. phot_table 2122.71, bkg_mean 44.29, aperture.area 50.27)
# ROI 2 initial (1085.9,936.3) → refined (1087.9,939.3)
# [DEBUG] In iterative: median=0.15, min=-18.65, max=9897.21
# ROI 3 initial (1205.9,936.3) → refined (1207.2,929.6)
# [DEBUG] In iterative: median=0.15, min=-18.65, max=9897.21
# [Info] Negative flux (-2.04) at r=2.0 for (1207.2,929.6); continuing. phot_table 595.82, bkg_mean 47.58, aperture.area 12.57)
# [INFO] Using common aperture radius = 22.00 px, annulus outer radius = 30.00 px, minimum radii was 15.00
# ROI 0: flux=298241.9, Bkg=3.68, RMS=4.29
# ROI 1: flux=293808.6, Bkg=4.76, RMS=4.19
# ROI 2: flux=321944.3, Bkg=5.14, RMS=4.22
# ROI 3: flux=326743.3, Bkg=4.94, RMS=4.58
#
# Fluxes for AF969611.fits.gz:
#    I0=298241.92, I90=293808.64, I45=321944.30, I135=326743.33
# [Info] Detected 4 sources in defined ROIs.
#   ROI 1: x = 968.33, y = 929.01
#   ROI 2: x = 860.82, y = 930.10
#   ROI 3: x = 1095.43, y = 931.16
#   ROI 4: x = 1202.86, y = 930.28
# ROI 0 initial (860.8,930.1) → refined (861.1,929.8)
# [DEBUG] In iterative: median=0.09, min=-20.87, max=56862.61
# ROI 1 initial (980.8,930.1) → refined (980.3,922.6)
# [DEBUG] In iterative: median=0.09, min=-20.87, max=56862.61
# [Info] Negative flux (-444.91) at r=2.0 for (980.3,922.6); continuing. phot_table 2198.76, bkg_mean 210.38, aperture.area 12.57)
# [Info] Negative flux (-2196.18) at r=3.0 for (980.3,922.6); continuing. phot_table 5386.35, bkg_mean 268.18, aperture.area 28.27)
# [Info] Negative flux (-2038.55) at r=4.0 for (980.3,922.6); continuing. phot_table 10573.75, bkg_mean 250.91, aperture.area 50.27)
# ROI 2 initial (1092.8,930.1) → refined (1094.0,932.1)
# [DEBUG] In iterative: median=0.09, min=-20.87, max=56862.61
# ROI 3 initial (1212.8,930.1) → refined (1213.8,922.9)
# [DEBUG] In iterative: median=0.09, min=-20.87, max=56862.61
# [Info] Negative flux (-536.51) at r=2.0 for (1213.8,922.9); continuing. phot_table 2135.31, bkg_mean 212.62, aperture.area 12.57)
# [Info] Negative flux (-942.67) at r=3.0 for (1213.8,922.9); continuing. phot_table 5213.03, bkg_mean 217.71, aperture.area 28.27)
# [INFO] Using common aperture radius = 23.00 px, annulus outer radius = 30.00 px, minimum radii was 15.00
# ROI 0: flux=1860640.0, Bkg=11.64, RMS=5.42
# ROI 1: flux=1831350.4, Bkg=15.01, RMS=9.77
# ROI 2: flux=2058087.2, Bkg=12.65, RMS=5.30
# ROI 3: flux=2074125.9, Bkg=16.29, RMS=12.98
#
# Fluxes for AF969612.fits.gz:
#    I0=1860639.98, I90=1831350.36, I45=2058087.16, I135=2074125.86
# [Info] Detected 4 sources in defined ROIs.
#   ROI 1: x = 986.38, y = 935.62
#   ROI 2: x = 875.26, y = 936.75
#   ROI 3: x = 1224.85, y = 937.34
#   ROI 4: x = 1113.63, y = 938.21
# ROI 0 initial (875.3,936.7) → refined (874.7,937.2)
# [DEBUG] In iterative: median=0.05, min=-19.43, max=3401.50
# ROI 1 initial (995.3,936.7) → refined (993.8,930.5)
# [DEBUG] In iterative: median=0.05, min=-19.43, max=3401.50
# [Info] Negative flux (-556.16) at r=2.0 for (993.8,930.5); continuing. phot_table 1959.80, bkg_mean 200.21, aperture.area 12.57)
# ROI 2 initial (1107.3,936.7) → refined (1108.0,941.8)
# [DEBUG] In iterative: median=0.05, min=-19.43, max=3401.50
# [Info] Negative flux (-632.61) at r=2.0 for (1108.0,941.8); continuing. phot_table 4794.08, bkg_mean 431.84, aperture.area 12.57)
# ROI 3 initial (1227.3,936.7) → refined (1227.2,935.1)
# [DEBUG] In iterative: median=0.05, min=-19.43, max=3401.50
# [INFO] Using common aperture radius = 21.00 px, annulus outer radius = 32.00 px, minimum radii was 16.00
# ROI 0: flux=222676.0, Bkg=5.95, RMS=4.18
# ROI 1: flux=225815.0, Bkg=6.03, RMS=4.22
# ROI 2: flux=195501.1, Bkg=7.19, RMS=4.63
# ROI 3: flux=204598.9, Bkg=6.15, RMS=4.84
#
# Fluxes for AF969613.fits.gz:
#    I0=222675.96, I90=225815.03, I45=195501.08, I135=204598.89
# [Info] Detected 4 sources in defined ROIs.
#   ROI 1: x = 968.12, y = 931.13
#   ROI 2: x = 1201.28, y = 932.67
#   ROI 3: x = 861.58, y = 932.22
#   ROI 4: x = 1094.78, y = 933.47
# ROI 0 initial (861.6,932.2) → refined (862.0,931.5)
# [DEBUG] In iterative: median=0.11, min=-18.50, max=40988.54
# ROI 1 initial (981.6,932.2) → refined (982.6,925.3)
# [DEBUG] In iterative: median=0.11, min=-18.50, max=40988.54
# [Info] Negative flux (-413.91) at r=2.0 for (982.6,925.3); continuing. phot_table 1962.87, bkg_mean 189.14, aperture.area 12.57)
# [Info] Negative flux (-1758.70) at r=3.0 for (982.6,925.3); continuing. phot_table 4727.19, bkg_mean 229.39, aperture.area 28.27)
# [Info] Negative flux (-1185.08) at r=4.0 for (982.6,925.3); continuing. phot_table 9024.91, bkg_mean 203.12, aperture.area 50.27)
# ROI 2 initial (1093.6,932.2) → refined (1095.1,932.6)
# [DEBUG] In iterative: median=0.11, min=-18.50, max=40988.54
# ROI 3 initial (1213.6,932.2) → refined (1215.3,924.7)
# [DEBUG] In iterative: median=0.11, min=-18.50, max=40988.54
# [Info] Negative flux (-272.28) at r=2.0 for (1215.3,924.7); continuing. phot_table 1514.79, bkg_mean 142.21, aperture.area 12.57)
# [Info] Negative flux (-474.64) at r=3.0 for (1215.3,924.7); continuing. phot_table 3573.86, bkg_mean 143.19, aperture.area 28.27)
# [Info] Negative flux (-680.33) at r=4.0 for (1215.3,924.7); continuing. phot_table 6784.59, bkg_mean 148.51, aperture.area 50.27)
# [INFO] Using common aperture radius = 27.00 px, annulus outer radius = 34.00 px, minimum radii was 17.00
# ROI 0: flux=1999661.6, Bkg=7.92, RMS=5.11
# ROI 1: flux=1962722.9, Bkg=10.18, RMS=6.57
# ROI 2: flux=2205568.7, Bkg=8.68, RMS=5.29
# ROI 3: flux=2199596.9, Bkg=10.43, RMS=9.74
#
# Fluxes for AF969614.fits.gz:
#    I0=1999661.59, I90=1962722.89, I45=2205568.68, I135=2199596.90
# [Info] Detected 4 sources in defined ROIs.
#   ROI 1: x = 965.27, y = 930.78
#   ROI 2: x = 1200.31, y = 931.76
#   ROI 3: x = 857.46, y = 931.91
#   ROI 4: x = 1092.52, y = 932.64
# ROI 0 initial (857.5,931.9) → refined (856.9,932.4)
# [DEBUG] In iterative: median=0.15, min=-19.47, max=18035.93
# ROI 1 initial (977.5,931.9) → refined (976.5,924.5)
# [DEBUG] In iterative: median=0.15, min=-19.47, max=18035.93
# [Info] Negative flux (-202.17) at r=2.0 for (976.5,924.5); continuing. phot_table 809.09, bkg_mean 80.47, aperture.area 12.57)
# [Info] Negative flux (-456.97) at r=3.0 for (976.5,924.5); continuing. phot_table 2004.60, bkg_mean 87.06, aperture.area 28.27)
# [Info] Negative flux (-92.71) at r=4.0 for (976.5,924.5); continuing. phot_table 3880.67, bkg_mean 79.05, aperture.area 50.27)
# ROI 2 initial (1089.5,931.9) → refined (1089.5,935.1)
# [DEBUG] In iterative: median=0.15, min=-19.47, max=18035.93
# [Info] Negative flux (-11788.61) at r=2.0 for (1089.5,935.1); continuing. phot_table 37590.61, bkg_mean 3929.47, aperture.area 12.57)
# ROI 3 initial (1209.5,931.9) → refined (1209.0,924.9)
# [DEBUG] In iterative: median=0.15, min=-19.47, max=18035.93
# [Info] Negative flux (-119.79) at r=2.0 for (1209.0,924.9); continuing. phot_table 1255.44, bkg_mean 109.44, aperture.area 12.57)
# [INFO] Using common aperture radius = 22.00 px, annulus outer radius = 30.00 px, minimum radii was 15.00
# ROI 0: flux=551662.5, Bkg=3.91, RMS=4.56
# ROI 1: flux=545517.1, Bkg=4.99, RMS=5.12
# ROI 2: flux=616200.2, Bkg=3.73, RMS=4.02
# ROI 3: flux=621286.2, Bkg=4.88, RMS=5.67
#
# Fluxes for AF969615.fits.gz:
#    I0=551662.51, I90=545517.06, I45=616200.21, I135=621286.17
# [Info] Detected 4 sources in defined ROIs.
#   ROI 1: x = 966.94, y = 930.75
#   ROI 2: x = 859.12, y = 931.86
#   ROI 3: x = 1202.32, y = 932.36
#   ROI 4: x = 1094.55, y = 933.18
# ROI 0 initial (859.1,931.9) → refined (858.8,932.1)
# [DEBUG] In iterative: median=0.14, min=-18.58, max=16328.36
# ROI 1 initial (979.1,931.9) → refined (978.1,924.6)
# [DEBUG] In iterative: median=0.14, min=-18.58, max=16328.36
# [Info] Negative flux (-198.81) at r=2.0 for (978.1,924.6); continuing. phot_table 856.20, bkg_mean 83.95, aperture.area 12.57)
# [Info] Negative flux (-503.88) at r=3.0 for (978.1,924.6); continuing. phot_table 2161.84, bkg_mean 94.28, aperture.area 28.27)
# [Info] Negative flux (-219.97) at r=4.0 for (978.1,924.6); continuing. phot_table 4240.99, bkg_mean 88.75, aperture.area 50.27)
# ROI 2 initial (1091.1,931.9) → refined (1092.0,935.1)
# [DEBUG] In iterative: median=0.14, min=-18.58, max=16328.36
# [Info] Negative flux (-3905.28) at r=2.0 for (1092.0,935.1); continuing. phot_table 62040.12, bkg_mean 5247.77, aperture.area 12.57)
# ROI 3 initial (1211.1,931.9) → refined (1211.4,925.0)
# [DEBUG] In iterative: median=0.14, min=-18.58, max=16328.36
# [Info] Negative flux (-204.71) at r=2.0 for (1211.4,925.0); continuing. phot_table 1201.52, bkg_mean 111.90, aperture.area 12.57)
# [Info] Negative flux (-321.49) at r=3.0 for (1211.4,925.0); continuing. phot_table 2893.03, bkg_mean 113.69, aperture.area 28.27)
# [INFO] Using common aperture radius = 22.00 px, annulus outer radius = 30.00 px, minimum radii was 15.00
# ROI 0: flux=558882.3, Bkg=3.90, RMS=4.44
# ROI 1: flux=549605.6, Bkg=5.11, RMS=5.04
# ROI 2: flux=624925.2, Bkg=4.04, RMS=4.58
# ROI 3: flux=625697.9, Bkg=5.48, RMS=5.74
#
# Fluxes for AF969616.fits.gz:
#    I0=558882.29, I90=549605.64, I45=624925.18, I135=625697.87
# [Info] Detected 4 sources in defined ROIs.
#   ROI 1: x = 967.65, y = 929.14
#   ROI 2: x = 859.82, y = 930.24
#   ROI 3: x = 1201.78, y = 930.94
#   ROI 4: x = 1093.99, y = 931.79
# ROI 0 initial (859.8,930.2) → refined (860.2,929.8)
# [DEBUG] In iterative: median=0.14, min=-18.91, max=19157.21
# ROI 1 initial (979.8,930.2) → refined (979.3,922.6)
# [DEBUG] In iterative: median=0.14, min=-18.91, max=19157.21
# [Info] Negative flux (-24.15) at r=2.0 for (979.3,922.6); continuing. phot_table 777.67, bkg_mean 63.81, aperture.area 12.57)
# [Info] Negative flux (-262.40) at r=3.0 for (979.3,922.6); continuing. phot_table 1791.95, bkg_mean 72.66, aperture.area 28.27)
# [Info] Negative flux (-322.33) at r=4.0 for (979.3,922.6); continuing. phot_table 3315.11, bkg_mean 72.36, aperture.area 50.27)
# ROI 2 initial (1091.8,930.2) → refined (1093.6,931.8)
# [DEBUG] In iterative: median=0.14, min=-18.91, max=19157.21
# ROI 3 initial (1211.8,930.2) → refined (1213.0,922.2)
# [DEBUG] In iterative: median=0.14, min=-18.91, max=19157.21
# [Info] Negative flux (-76.80) at r=2.0 for (1213.0,922.2); continuing. phot_table 483.30, bkg_mean 44.57, aperture.area 12.57)
# [Info] Negative flux (-170.45) at r=3.0 for (1213.0,922.2); continuing. phot_table 1153.95, bkg_mean 46.84, aperture.area 28.27)
# [Info] Negative flux (-196.47) at r=4.0 for (1213.0,922.2); continuing. phot_table 2188.12, bkg_mean 47.44, aperture.area 50.27)
# [Info] Negative flux (-105.20) at r=5.0 for (1213.0,922.2); continuing. phot_table 3715.53, bkg_mean 48.65, aperture.area 78.54)
# [INFO] Using common aperture radius = 24.00 px, annulus outer radius = 30.00 px, minimum radii was 15.00
# ROI 0: flux=554183.9, Bkg=3.40, RMS=4.41
# ROI 1: flux=549989.3, Bkg=3.88, RMS=4.74
# ROI 2: flux=620160.3, Bkg=3.56, RMS=4.24
# ROI 3: flux=618927.1, Bkg=4.56, RMS=5.37
#
# Fluxes for AF969617.fits.gz:
#    I0=554183.92, I90=549989.29, I45=620160.27, I135=618927.09
# [Info] Detected 4 sources in defined ROIs.
#   ROI 1: x = 966.60, y = 927.53
#   ROI 2: x = 858.73, y = 928.63
#   ROI 3: x = 1202.15, y = 928.78
#   ROI 4: x = 1094.35, y = 929.63
# ROI 0 initial (858.7,928.6) → refined (858.6,928.7)
# [DEBUG] In iterative: median=0.13, min=-19.47, max=18109.24
# ROI 1 initial (978.7,928.6) → refined (977.8,921.7)
# [DEBUG] In iterative: median=0.13, min=-19.47, max=18109.24
# [Info] Negative flux (-261.97) at r=2.0 for (977.8,921.7); continuing. phot_table 859.22, bkg_mean 89.22, aperture.area 12.57)
# [Info] Negative flux (-570.19) at r=3.0 for (977.8,921.7); continuing. phot_table 2134.86, bkg_mean 95.67, aperture.area 28.27)
# [Info] Negative flux (-104.75) at r=4.0 for (977.8,921.7); continuing. phot_table 4219.23, bkg_mean 86.02, aperture.area 50.27)
# ROI 2 initial (1090.7,928.6) → refined (1091.5,932.0)
# [DEBUG] In iterative: median=0.13, min=-19.47, max=18109.24
# [Info] Negative flux (-11632.62) at r=2.0 for (1091.5,932.0); continuing. phot_table 50973.69, bkg_mean 4982.05, aperture.area 12.57)
# ROI 3 initial (1210.7,928.6) → refined (1210.8,921.7)
# [DEBUG] In iterative: median=0.13, min=-19.47, max=18109.24
# [Info] Negative flux (-224.59) at r=2.0 for (1210.8,921.7); continuing. phot_table 1173.47, bkg_mean 111.25, aperture.area 12.57)
# [Info] Negative flux (-174.34) at r=3.0 for (1210.8,921.7); continuing. phot_table 2925.58, bkg_mean 109.64, aperture.area 28.27)
# [INFO] Using common aperture radius = 22.00 px, annulus outer radius = 30.00 px, minimum radii was 15.00
# ROI 0: flux=560098.3, Bkg=4.05, RMS=4.30
# ROI 1: flux=553289.7, Bkg=4.64, RMS=5.15
# ROI 2: flux=622806.1, Bkg=4.32, RMS=4.44
# ROI 3: flux=628268.7, Bkg=4.79, RMS=4.94
#
# Fluxes for AF969618.fits.gz:
#    I0=560098.26, I90=553289.74, I45=622806.09, I135=628268.72
# [Info] Detected 4 sources in defined ROIs.
#   ROI 1: x = 967.63, y = 926.82
#   ROI 2: x = 859.76, y = 927.90
#   ROI 3: x = 1203.12, y = 928.47
#   ROI 4: x = 1095.28, y = 929.30
# ROI 0 initial (859.8,927.9) → refined (859.9,927.8)
# [DEBUG] In iterative: median=0.14, min=-20.49, max=17370.02
# ROI 1 initial (979.8,927.9) → refined (979.0,920.5)
# [DEBUG] In iterative: median=0.14, min=-20.49, max=17370.02
# [Info] Negative flux (-119.20) at r=2.0 for (979.0,920.5); continuing. phot_table 787.62, bkg_mean 72.16, aperture.area 12.57)
# [Info] Negative flux (-693.60) at r=3.0 for (979.0,920.5); continuing. phot_table 1913.19, bkg_mean 92.20, aperture.area 28.27)
# [Info] Negative flux (-373.24) at r=4.0 for (979.0,920.5); continuing. phot_table 3692.38, bkg_mean 80.88, aperture.area 50.27)
# ROI 2 initial (1091.8,927.9) → refined (1093.1,930.9)
# [DEBUG] In iterative: median=0.14, min=-20.49, max=17370.02
# ROI 3 initial (1211.8,927.9) → refined (1212.5,920.8)
# [DEBUG] In iterative: median=0.14, min=-20.49, max=17370.02
# [Info] Negative flux (-136.10) at r=2.0 for (1212.5,920.8); continuing. phot_table 870.61, bkg_mean 80.11, aperture.area 12.57)
# [INFO] Using common aperture radius = 23.00 px, annulus outer radius = 30.00 px, minimum radii was 15.00
# ROI 0: flux=552254.0, Bkg=3.64, RMS=4.02
# ROI 1: flux=544664.1, Bkg=4.41, RMS=4.68
# ROI 2: flux=616116.9, Bkg=3.77, RMS=3.87
# ROI 3: flux=619021.5, Bkg=4.60, RMS=5.57
#
# Fluxes for AF969619.fits.gz:
#    I0=552253.95, I90=544664.09, I45=616116.94, I135=619021.49
# [Info] Detected 4 sources in defined ROIs.
#   ROI 1: x = 966.18, y = 929.67
#   ROI 2: x = 858.35, y = 930.78
#   ROI 3: x = 1093.61, y = 932.63
#   ROI 4: x = 1201.43, y = 931.80
# ROI 0 initial (858.4,930.8) → refined (857.8,931.3)
# [DEBUG] In iterative: median=0.14, min=-18.77, max=18193.42
# ROI 1 initial (978.4,930.8) → refined (977.1,923.4)
# [DEBUG] In iterative: median=0.14, min=-18.77, max=18193.42
# [Info] Negative flux (-148.87) at r=2.0 for (977.1,923.4); continuing. phot_table 794.64, bkg_mean 75.08, aperture.area 12.57)
# [Info] Negative flux (-736.03) at r=3.0 for (977.1,923.4); continuing. phot_table 1932.96, bkg_mean 94.40, aperture.area 28.27)
# [Info] Negative flux (-441.84) at r=4.0 for (977.1,923.4); continuing. phot_table 3854.91, bkg_mean 85.48, aperture.area 50.27)
# ROI 2 initial (1090.4,930.8) → refined (1091.4,934.2)
# [DEBUG] In iterative: median=0.14, min=-18.77, max=18193.42
# ROI 3 initial (1210.4,930.8) → refined (1210.8,923.9)
# [DEBUG] In iterative: median=0.14, min=-18.77, max=18193.42
# [Info] Negative flux (-184.71) at r=2.0 for (1210.8,923.9); continuing. phot_table 841.91, bkg_mean 81.70, aperture.area 12.57)
# [Info] Negative flux (-46.31) at r=3.0 for (1210.8,923.9); continuing. phot_table 2034.94, bkg_mean 73.61, aperture.area 28.27)
# [INFO] Using common aperture radius = 22.00 px, annulus outer radius = 30.00 px, minimum radii was 15.00
# ROI 0: flux=559021.2, Bkg=4.21, RMS=3.95
# ROI 1: flux=553602.1, Bkg=5.06, RMS=4.74
# ROI 2: flux=624859.6, Bkg=4.60, RMS=4.61
# ROI 3: flux=622708.3, Bkg=5.30, RMS=5.79
#
# Fluxes for AF969620.fits.gz:
#    I0=559021.24, I90=553602.05, I45=624859.64, I135=622708.30
# [Info] Detected 4 sources in defined ROIs.
#   ROI 1: x = 967.72, y = 928.25
#   ROI 2: x = 859.91, y = 929.34
#   ROI 3: x = 1203.28, y = 929.83
#   ROI 4: x = 1095.49, y = 930.70
# ROI 0 initial (859.9,929.3) → refined (860.3,928.9)
# [DEBUG] In iterative: median=0.14, min=-18.66, max=20344.28
# ROI 1 initial (979.9,929.3) → refined (979.4,921.5)
# [DEBUG] In iterative: median=0.14, min=-18.66, max=20344.28
# [Info] Negative flux (-115.47) at r=2.0 for (979.4,921.5); continuing. phot_table 675.91, bkg_mean 62.98, aperture.area 12.57)
# [Info] Negative flux (-446.76) at r=3.0 for (979.4,921.5); continuing. phot_table 1595.58, bkg_mean 72.23, aperture.area 28.27)
# [Info] Negative flux (-312.75) at r=4.0 for (979.4,921.5); continuing. phot_table 3095.77, bkg_mean 67.81, aperture.area 50.27)
# ROI 2 initial (1091.9,929.3) → refined (1093.5,932.0)
# [DEBUG] In iterative: median=0.14, min=-18.66, max=20344.28
# ROI 3 initial (1211.9,929.3) → refined (1212.9,922.0)
# [DEBUG] In iterative: median=0.14, min=-18.66, max=20344.28
# [Info] Negative flux (-128.36) at r=2.0 for (1212.9,922.0); continuing. phot_table 885.47, bkg_mean 80.68, aperture.area 12.57)
# [Info] Negative flux (-334.03) at r=3.0 for (1212.9,922.0); continuing. phot_table 2094.21, bkg_mean 85.88, aperture.area 28.27)
# [INFO] Using common aperture radius = 22.00 px, annulus outer radius = 28.00 px, minimum radii was 14.00
# ROI 0: flux=550807.7, Bkg=3.67, RMS=4.43
# ROI 1: flux=543094.2, Bkg=4.72, RMS=4.90
# ROI 2: flux=612474.4, Bkg=4.56, RMS=4.15
# ROI 3: flux=612286.7, Bkg=5.77, RMS=5.63
#
# Fluxes for AF969621.fits.gz:
#    I0=550807.67, I90=543094.18, I45=612474.44, I135=612286.67
# [Info] Detected 4 sources in defined ROIs.
#   ROI 1: x = 967.98, y = 930.23
#   ROI 2: x = 860.14, y = 931.34
#   ROI 3: x = 1203.14, y = 931.76
#   ROI 4: x = 1095.34, y = 932.65
# ROI 0 initial (860.1,931.3) → refined (860.2,931.1)
# [DEBUG] In iterative: median=0.13, min=-18.58, max=13514.41
# ROI 1 initial (980.1,931.3) → refined (979.7,923.7)
# [DEBUG] In iterative: median=0.13, min=-18.58, max=13514.41
# [Info] Negative flux (-256.50) at r=2.0 for (979.7,923.7); continuing. phot_table 718.75, bkg_mean 77.61, aperture.area 12.57)
# [Info] Negative flux (-654.72) at r=3.0 for (979.7,923.7); continuing. phot_table 1799.95, bkg_mean 86.82, aperture.area 28.27)
# [Info] Negative flux (-565.73) at r=4.0 for (979.7,923.7); continuing. phot_table 3585.95, bkg_mean 82.60, aperture.area 50.27)
# ROI 2 initial (1092.1,931.3) → refined (1093.4,933.9)
# [DEBUG] In iterative: median=0.13, min=-18.58, max=13514.41
# ROI 3 initial (1212.1,931.3) → refined (1212.9,924.0)
# [DEBUG] In iterative: median=0.13, min=-18.58, max=13514.41
# [Info] Negative flux (-240.61) at r=2.0 for (1212.9,924.0); continuing. phot_table 980.00, bkg_mean 97.13, aperture.area 12.57)
# [Info] Negative flux (-361.06) at r=3.0 for (1212.9,924.0); continuing. phot_table 2367.17, bkg_mean 96.49, aperture.area 28.27)
# [Info] Negative flux (-32.02) at r=4.0 for (1212.9,924.0); continuing. phot_table 4614.87, bkg_mean 92.45, aperture.area 50.27)
# [INFO] Using common aperture radius = 23.00 px, annulus outer radius = 32.00 px, minimum radii was 16.00
# ROI 0: flux=562316.9, Bkg=3.84, RMS=4.01
# ROI 1: flux=552676.1, Bkg=4.40, RMS=4.99
# ROI 2: flux=627796.6, Bkg=4.56, RMS=4.24
# ROI 3: flux=627162.7, Bkg=5.31, RMS=5.61
#
# Fluxes for AF969622.fits.gz:
#    I0=562316.87, I90=552676.07, I45=627796.56, I135=627162.71
# [Info] Detected 4 sources in defined ROIs.
#   ROI 1: x = 968.29, y = 930.84
#   ROI 2: x = 860.45, y = 931.94
#   ROI 3: x = 1202.75, y = 931.73
#   ROI 4: x = 1094.90, y = 932.52
# ROI 0 initial (860.5,931.9) → refined (859.9,932.4)
# [DEBUG] In iterative: median=0.15, min=-18.39, max=15514.23
# ROI 1 initial (980.5,931.9) → refined (979.5,924.4)
# [DEBUG] In iterative: median=0.15, min=-18.39, max=15514.23
# [Info] Negative flux (-195.52) at r=2.0 for (979.5,924.4); continuing. phot_table 721.35, bkg_mean 72.96, aperture.area 12.57)
# [Info] Negative flux (-841.87) at r=3.0 for (979.5,924.4); continuing. phot_table 1772.21, bkg_mean 92.45, aperture.area 28.27)
# [Info] Negative flux (-805.69) at r=4.0 for (979.5,924.4); continuing. phot_table 3457.97, bkg_mean 84.82, aperture.area 50.27)
# ROI 2 initial (1092.5,931.9) → refined (1092.4,934.6)
# [DEBUG] In iterative: median=0.15, min=-18.39, max=15514.23
# [Info] Negative flux (-5735.11) at r=2.0 for (1092.4,934.6); continuing. phot_table 60193.01, bkg_mean 5246.39, aperture.area 12.57)
# ROI 3 initial (1212.5,931.9) → refined (1211.8,924.6)
# [DEBUG] In iterative: median=0.15, min=-18.39, max=15514.23
# [Info] Negative flux (-287.85) at r=2.0 for (1211.8,924.6); continuing. phot_table 1071.26, bkg_mean 108.15, aperture.area 12.57)
# [INFO] Using common aperture radius = 22.00 px, annulus outer radius = 30.00 px, minimum radii was 15.00
# ROI 0: flux=551397.3, Bkg=4.15, RMS=4.11
# ROI 1: flux=543298.6, Bkg=5.06, RMS=4.88
# ROI 2: flux=616789.2, Bkg=4.14, RMS=4.89
# ROI 3: flux=619039.2, Bkg=5.04, RMS=5.21
#
# Fluxes for AF969623.fits.gz:
#    I0=551397.31, I90=543298.59, I45=616789.21, I135=619039.15
# [Info] Detected 4 sources in defined ROIs.
#   ROI 1: x = 966.22, y = 931.56
#   ROI 2: x = 858.38, y = 932.67
#   ROI 3: x = 1093.78, y = 933.52
#   ROI 4: x = 1201.61, y = 932.68
# ROI 0 initial (858.4,932.7) → refined (857.7,933.3)
# [DEBUG] In iterative: median=0.14, min=-18.93, max=16347.18
# ROI 1 initial (978.4,932.7) → refined (976.9,925.5)
# [DEBUG] In iterative: median=0.14, min=-18.93, max=16347.18
# [Info] Negative flux (-261.64) at r=2.0 for (976.9,925.5); continuing. phot_table 970.45, bkg_mean 98.05, aperture.area 12.57)
# [Info] Negative flux (-647.64) at r=3.0 for (976.9,925.5); continuing. phot_table 2343.47, bkg_mean 105.79, aperture.area 28.27)
# [Info] Negative flux (-4.42) at r=4.0 for (976.9,925.5); continuing. phot_table 4618.01, bkg_mean 91.96, aperture.area 50.27)
# ROI 2 initial (1090.4,932.7) → refined (1090.4,936.3)
# [DEBUG] In iterative: median=0.14, min=-18.93, max=16347.18
# [Info] Negative flux (-4329.03) at r=2.0 for (1090.4,936.3); continuing. phot_table 33577.53, bkg_mean 3016.51, aperture.area 12.57)
# ROI 3 initial (1210.4,932.7) → refined (1209.7,926.1)
# [DEBUG] In iterative: median=0.14, min=-18.93, max=16347.18
# [Info] Negative flux (-506.87) at r=2.0 for (1209.7,926.1); continuing. phot_table 1661.84, bkg_mean 172.58, aperture.area 12.57)
# [Info] Negative flux (-111.94) at r=3.0 for (1209.7,926.1); continuing. phot_table 4115.17, bkg_mean 149.50, aperture.area 28.27)
# [INFO] Using common aperture radius = 22.00 px, annulus outer radius = 30.00 px, minimum radii was 15.00
# ROI 0: flux=559542.9, Bkg=4.26, RMS=4.33
# ROI 1: flux=552866.2, Bkg=4.99, RMS=4.73
# ROI 2: flux=625383.4, Bkg=4.27, RMS=4.04
# ROI 3: flux=630647.3, Bkg=5.08, RMS=5.84
#
# Fluxes for AF969624.fits.gz:
#    I0=559542.87, I90=552866.17, I45=625383.41, I135=630647.27
# [Info] Detected 4 sources in defined ROIs.
#   ROI 1: x = 961.25, y = 936.00
#   ROI 2: x = 852.44, y = 937.10
#   ROI 3: x = 1196.26, y = 938.20
#   ROI 4: x = 1087.58, y = 939.05
# ROI 0 initial (852.4,937.1) → refined (852.0,937.3)
# [DEBUG] In iterative: median=0.11, min=-18.51, max=18371.12
# ROI 1 initial (972.4,937.1) → refined (971.1,929.8)
# [DEBUG] In iterative: median=0.11, min=-18.51, max=18371.12
# [Info] Negative flux (-535.74) at r=2.0 for (971.1,929.8); continuing. phot_table 2900.42, bkg_mean 273.44, aperture.area 12.57)
# [Info] Negative flux (-44.63) at r=3.0 for (971.1,929.8); continuing. phot_table 7016.00, bkg_mean 249.72, aperture.area 28.27)
# ROI 2 initial (1084.4,937.1) → refined (1085.8,940.0)
# [DEBUG] In iterative: median=0.11, min=-18.51, max=18371.12
# ROI 3 initial (1204.4,937.1) → refined (1205.1,930.9)
# [DEBUG] In iterative: median=0.11, min=-18.51, max=18371.12
# [Info] Negative flux (-388.85) at r=2.0 for (1205.1,930.9); continuing. phot_table 3198.28, bkg_mean 285.46, aperture.area 12.57)
# [INFO] Using common aperture radius = 23.00 px, annulus outer radius = 32.00 px, minimum radii was 16.00
# ROI 0: flux=1020486.6, Bkg=13.38, RMS=5.12
# ROI 1: flux=1015301.6, Bkg=15.25, RMS=6.16
# ROI 2: flux=1103772.8, Bkg=17.12, RMS=5.45
# ROI 3: flux=1113883.1, Bkg=18.16, RMS=9.18
#
# Fluxes for AF969625.fits.gz:
#    I0=1020486.56, I90=1015301.56, I45=1103772.82, I135=1113883.05
# [Info] Detected 4 sources in defined ROIs.
#   ROI 1: x = 964.14, y = 937.17
#   ROI 2: x = 855.31, y = 938.28
#   ROI 3: x = 1199.14, y = 938.75
#   ROI 4: x = 1090.39, y = 939.57
# ROI 0 initial (855.3,938.3) → refined (855.1,938.2)
# [DEBUG] In iterative: median=0.10, min=-19.63, max=12153.40
# ROI 1 initial (975.3,938.3) → refined (975.0,931.2)
# [DEBUG] In iterative: median=0.10, min=-19.63, max=12153.40
# [Info] Negative flux (-299.75) at r=2.0 for (975.0,931.2); continuing. phot_table 2789.63, bkg_mean 245.85, aperture.area 12.57)
# [Info] Negative flux (-375.32) at r=3.0 for (975.0,931.2); continuing. phot_table 6477.84, bkg_mean 242.38, aperture.area 28.27)
# ROI 2 initial (1087.3,938.3) → refined (1088.1,940.6)
# [DEBUG] In iterative: median=0.10, min=-19.63, max=12153.40
# ROI 3 initial (1207.3,938.3) → refined (1207.8,932.1)
# [DEBUG] In iterative: median=0.10, min=-19.63, max=12153.40
# [Info] Negative flux (-1042.83) at r=2.0 for (1207.8,932.1); continuing. phot_table 3988.81, bkg_mean 400.41, aperture.area 12.57)
# [Info] Negative flux (-64.95) at r=3.0 for (1207.8,932.1); continuing. phot_table 9742.04, bkg_mean 346.85, aperture.area 28.27)
# [INFO] Using common aperture radius = 24.00 px, annulus outer radius = 36.00 px, minimum radii was 18.00
# ROI 0: flux=1025175.3, Bkg=13.10, RMS=5.51
# ROI 1: flux=1016496.4, Bkg=15.09, RMS=6.75
# ROI 2: flux=1107867.9, Bkg=17.03, RMS=5.18
# ROI 3: flux=1122870.8, Bkg=17.81, RMS=9.13
#
# Fluxes for AF969626.fits.gz:
#    I0=1025175.35, I90=1016496.41, I45=1107867.90, I135=1122870.84
# [Info] Detected 4 sources in defined ROIs.
#   ROI 1: x = 962.08, y = 935.70
#   ROI 2: x = 853.26, y = 936.80
#   ROI 3: x = 1197.38, y = 937.76
#   ROI 4: x = 1088.66, y = 938.59
# ROI 0 initial (853.3,936.8) → refined (852.8,937.2)
# [DEBUG] In iterative: median=0.11, min=-19.63, max=21446.29
# ROI 1 initial (973.3,936.8) → refined (972.1,929.6)
# [DEBUG] In iterative: median=0.11, min=-19.63, max=21446.29
# [Info] Negative flux (-317.82) at r=2.0 for (972.1,929.6); continuing. phot_table 2679.20, bkg_mean 238.50, aperture.area 12.57)
# [Info] Negative flux (-994.72) at r=3.0 for (972.1,929.6); continuing. phot_table 6427.30, bkg_mean 262.50, aperture.area 28.27)
# ROI 2 initial (1085.3,936.8) → refined (1086.3,940.0)
# [DEBUG] In iterative: median=0.11, min=-19.63, max=21446.29
# ROI 3 initial (1205.3,936.8) → refined (1205.8,931.0)
# [DEBUG] In iterative: median=0.11, min=-19.63, max=21446.29
# [Info] Negative flux (-944.63) at r=2.0 for (1205.8,931.0); continuing. phot_table 3466.52, bkg_mean 351.03, aperture.area 12.57)
# [INFO] Using common aperture radius = 23.00 px, annulus outer radius = 32.00 px, minimum radii was 16.00
# ROI 0: flux=1019153.0, Bkg=13.49, RMS=5.07
# ROI 1: flux=1014164.0, Bkg=15.19, RMS=6.54
# ROI 2: flux=1102048.9, Bkg=17.22, RMS=5.62
# ROI 3: flux=1116795.6, Bkg=17.88, RMS=7.77
#
# Fluxes for AF969627.fits.gz:
#    I0=1019153.03, I90=1014163.97, I45=1102048.95, I135=1116795.62
# [Info] Detected 4 sources in defined ROIs.
#   ROI 1: x = 962.64, y = 934.26
#   ROI 2: x = 853.82, y = 935.35
#   ROI 3: x = 1198.38, y = 936.37
#   ROI 4: x = 1089.65, y = 937.22
# ROI 0 initial (853.8,935.3) → refined (854.2,934.8)
# [DEBUG] In iterative: median=0.12, min=-17.85, max=16709.19
# ROI 1 initial (973.8,935.3) → refined (973.5,927.9)
# [DEBUG] In iterative: median=0.12, min=-17.85, max=16709.19
# [Info] Negative flux (-596.10) at r=2.0 for (973.5,927.9); continuing. phot_table 2530.60, bkg_mean 248.81, aperture.area 12.57)
# [Info] Negative flux (-292.41) at r=3.0 for (973.5,927.9); continuing. phot_table 6147.83, bkg_mean 227.78, aperture.area 28.27)
# ROI 2 initial (1085.8,935.3) → refined (1087.9,937.9)
# [DEBUG] In iterative: median=0.12, min=-17.85, max=16709.19
# ROI 3 initial (1205.8,935.3) → refined (1207.3,929.2)
# [DEBUG] In iterative: median=0.12, min=-17.85, max=16709.19
# [Info] Negative flux (-742.33) at r=2.0 for (1207.3,929.2); continuing. phot_table 3715.89, bkg_mean 354.77, aperture.area 12.57)
# [Info] Negative flux (-139.73) at r=3.0 for (1207.3,929.2); continuing. phot_table 8925.90, bkg_mean 320.63, aperture.area 28.27)
# [INFO] Using common aperture radius = 24.00 px, annulus outer radius = 34.00 px, minimum radii was 17.00
# ROI 0: flux=1026426.9, Bkg=12.80, RMS=5.54
# ROI 1: flux=1019038.3, Bkg=14.83, RMS=6.27
# ROI 2: flux=1110535.9, Bkg=17.27, RMS=5.30
# ROI 3: flux=1124485.5, Bkg=16.81, RMS=8.01
#
# Fluxes for AF969628.fits.gz:
#    I0=1026426.86, I90=1019038.34, I45=1110535.89, I135=1124485.49
# [Info] Detected 4 sources in defined ROIs.
#   ROI 1: x = 963.86, y = 935.39
#   ROI 2: x = 855.06, y = 936.50
#   ROI 3: x = 1200.03, y = 937.46
#   ROI 4: x = 1091.28, y = 938.33
# ROI 0 initial (855.1,936.5) → refined (854.5,937.0)
# [DEBUG] In iterative: median=0.12, min=-18.40, max=16421.33
# ROI 1 initial (975.1,936.5) → refined (973.8,929.8)
# [DEBUG] In iterative: median=0.12, min=-18.40, max=16421.33
# [Info] Negative flux (-393.45) at r=2.0 for (973.8,929.8); continuing. phot_table 3650.71, bkg_mean 321.82, aperture.area 12.57)
# ROI 2 initial (1087.1,936.5) → refined (1088.1,940.4)
# [DEBUG] In iterative: median=0.12, min=-18.40, max=16421.33
# ROI 3 initial (1207.1,936.5) → refined (1207.4,931.5)
# [DEBUG] In iterative: median=0.12, min=-18.40, max=16421.33
# [Info] Negative flux (-1732.35) at r=2.0 for (1207.4,931.5); continuing. phot_table 7266.45, bkg_mean 716.10, aperture.area 12.57)
# [INFO] Using common aperture radius = 23.00 px, annulus outer radius = 34.00 px, minimum radii was 17.00
# ROI 0: flux=1018587.8, Bkg=13.23, RMS=5.39
# ROI 1: flux=1013364.4, Bkg=15.34, RMS=6.40
# ROI 2: flux=1098408.9, Bkg=17.62, RMS=6.16
# ROI 3: flux=1118489.1, Bkg=18.41, RMS=7.47
#
# Fluxes for AF969629.fits.gz:
#    I0=1018587.80, I90=1013364.44, I45=1098408.91, I135=1118489.12
# [Info] Detected 4 sources in defined ROIs.
#   ROI 1: x = 962.35, y = 933.79
#   ROI 2: x = 853.55, y = 934.89
#   ROI 3: x = 1088.88, y = 936.90
#   ROI 4: x = 1197.62, y = 936.08
# ROI 0 initial (853.6,934.9) → refined (853.8,934.5)
# [DEBUG] In iterative: median=0.12, min=-18.72, max=23069.32
# ROI 1 initial (973.6,934.9) → refined (973.2,927.6)
# [DEBUG] In iterative: median=0.12, min=-18.72, max=23069.32
# [Info] Negative flux (-294.60) at r=2.0 for (973.2,927.6); continuing. phot_table 2083.12, bkg_mean 189.21, aperture.area 12.57)
# ROI 2 initial (1085.6,934.9) → refined (1087.6,937.5)
# [DEBUG] In iterative: median=0.12, min=-18.72, max=23069.32
# ROI 3 initial (1205.6,934.9) → refined (1207.1,928.4)
# [DEBUG] In iterative: median=0.12, min=-18.72, max=23069.32
# [Info] Negative flux (-237.47) at r=2.0 for (1207.1,928.4); continuing. phot_table 2121.43, bkg_mean 187.72, aperture.area 12.57)
# [INFO] Using common aperture radius = 23.00 px, annulus outer radius = 32.00 px, minimum radii was 16.00
# ROI 0: flux=1022490.6, Bkg=14.16, RMS=5.70
# ROI 1: flux=1013661.8, Bkg=16.17, RMS=6.59
# ROI 2: flux=1107630.0, Bkg=17.31, RMS=5.45
# ROI 3: flux=1114732.2, Bkg=18.41, RMS=9.51
#
# Fluxes for AF969630.fits.gz:
#    I0=1022490.61, I90=1013661.80, I45=1107629.98, I135=1114732.25
# [Info] Detected 4 sources in defined ROIs.
#   ROI 1: x = 962.94, y = 935.73
#   ROI 2: x = 854.13, y = 936.86
#   ROI 3: x = 1199.18, y = 937.82
#   ROI 4: x = 1090.47, y = 938.69
# ROI 0 initial (854.1,936.9) → refined (853.8,937.0)
# [DEBUG] In iterative: median=0.11, min=-20.60, max=15221.25
# ROI 1 initial (974.1,936.9) → refined (973.1,929.8)
# [DEBUG] In iterative: median=0.11, min=-20.60, max=15221.25
# [Info] Negative flux (-87.13) at r=2.0 for (973.1,929.8); continuing. phot_table 2874.24, bkg_mean 235.66, aperture.area 12.57)
# ROI 2 initial (1086.1,936.9) → refined (1087.3,940.6)
# [DEBUG] In iterative: median=0.11, min=-20.60, max=15221.25
# [Info] Negative flux (-7436.49) at r=2.0 for (1087.3,940.6); continuing. phot_table 65853.71, bkg_mean 5832.25, aperture.area 12.57)
# ROI 3 initial (1206.1,936.9) → refined (1206.8,931.6)
# [DEBUG] In iterative: median=0.11, min=-20.60, max=15221.25
# [Info] Negative flux (-865.81) at r=2.0 for (1206.8,931.6); continuing. phot_table 5037.07, bkg_mean 469.74, aperture.area 12.57)
# [INFO] Using common aperture radius = 23.00 px, annulus outer radius = 32.00 px, minimum radii was 16.00
# ROI 0: flux=1019819.6, Bkg=13.28, RMS=5.17
# ROI 1: flux=1012443.4, Bkg=15.33, RMS=6.95
# ROI 2: flux=1100553.5, Bkg=18.19, RMS=5.69
# ROI 3: flux=1121179.3, Bkg=17.31, RMS=7.93
#
# Fluxes for AF969631.fits.gz:
#    I0=1019819.58, I90=1012443.36, I45=1100553.46, I135=1121179.31
# [Info] Detected 4 sources in defined ROIs.
#   ROI 1: x = 963.30, y = 935.44
#   ROI 2: x = 854.51, y = 936.54
#   ROI 3: x = 1199.19, y = 937.44
#   ROI 4: x = 1090.46, y = 938.32
# ROI 0 initial (854.5,936.5) → refined (854.5,936.5)
# [DEBUG] In iterative: median=0.11, min=-19.92, max=20140.22
# ROI 1 initial (974.5,936.5) → refined (973.8,929.8)
# [DEBUG] In iterative: median=0.11, min=-19.92, max=20140.22
# [Info] Negative flux (-566.14) at r=2.0 for (973.8,929.8); continuing. phot_table 2761.80, bkg_mean 264.83, aperture.area 12.57)
# [Info] Negative flux (-496.68) at r=3.0 for (973.8,929.8); continuing. phot_table 6662.59, bkg_mean 253.21, aperture.area 28.27)
# ROI 2 initial (1086.5,936.5) → refined (1088.1,939.8)
# [DEBUG] In iterative: median=0.11, min=-19.92, max=20140.22
# ROI 3 initial (1206.5,936.5) → refined (1207.6,930.9)
# [DEBUG] In iterative: median=0.11, min=-19.92, max=20140.22
# [Info] Negative flux (-604.93) at r=2.0 for (1207.6,930.9); continuing. phot_table 4196.36, bkg_mean 382.07, aperture.area 12.57)
# [INFO] Using common aperture radius = 23.00 px, annulus outer radius = 34.00 px, minimum radii was 17.00
# ROI 0: flux=1026138.7, Bkg=13.20, RMS=5.64
# ROI 1: flux=1016893.4, Bkg=15.40, RMS=6.75
# ROI 2: flux=1107394.1, Bkg=18.09, RMS=5.47
# ROI 3: flux=1125073.3, Bkg=17.20, RMS=7.71
#
# Fluxes for AF969632.fits.gz:
#    I0=1026138.70, I90=1016893.40, I45=1107394.12, I135=1125073.35
# [Info] Detected 4 sources in defined ROIs.
#   ROI 1: x = 962.01, y = 936.43
#   ROI 2: x = 853.17, y = 937.55
#   ROI 3: x = 1197.18, y = 938.59
#   ROI 4: x = 1088.46, y = 939.45
# ROI 0 initial (853.2,937.5) → refined (852.5,938.1)
# [DEBUG] In iterative: median=0.11, min=-19.27, max=17647.49
# ROI 1 initial (973.2,937.5) → refined (972.1,930.7)
# [DEBUG] In iterative: median=0.11, min=-19.27, max=17647.49
# [Info] Negative flux (-546.37) at r=2.0 for (972.1,930.7); continuing. phot_table 2760.84, bkg_mean 263.18, aperture.area 12.57)
# ROI 2 initial (1085.2,937.5) → refined (1086.2,940.8)
# [DEBUG] In iterative: median=0.11, min=-19.27, max=17647.49
# ROI 3 initial (1205.2,937.5) → refined (1205.7,932.0)
# [DEBUG] In iterative: median=0.11, min=-19.27, max=17647.49
# [Info] Negative flux (-731.70) at r=2.0 for (1205.7,932.0); continuing. phot_table 3658.71, bkg_mean 349.38, aperture.area 12.57)
# [INFO] Using common aperture radius = 22.00 px, annulus outer radius = 32.00 px, minimum radii was 16.00
# ROI 0: flux=1017580.4, Bkg=14.21, RMS=5.19
# ROI 1: flux=1006841.9, Bkg=16.41, RMS=7.56
# ROI 2: flux=1097746.3, Bkg=18.29, RMS=5.36
# ROI 3: flux=1107495.6, Bkg=19.53, RMS=9.48
#
# Fluxes for AF969633.fits.gz:
#    I0=1017580.40, I90=1006841.90, I45=1097746.33, I135=1107495.57
# [Info] Detected 4 sources in defined ROIs.
#   ROI 1: x = 963.66, y = 937.92
#   ROI 2: x = 854.85, y = 939.02
#   ROI 3: x = 1198.82, y = 939.69
#   ROI 4: x = 1090.07, y = 940.54
# ROI 0 initial (854.8,939.0) → refined (854.9,938.8)
# [DEBUG] In iterative: median=0.11, min=-19.83, max=20019.58
# ROI 1 initial (974.8,939.0) → refined (974.3,931.8)
# [DEBUG] In iterative: median=0.11, min=-19.83, max=20019.58
# [Info] Negative flux (-375.71) at r=2.0 for (974.3,931.8); continuing. phot_table 2468.67, bkg_mean 226.35, aperture.area 12.57)
# [Info] Negative flux (-716.60) at r=3.0 for (974.3,931.8); continuing. phot_table 6042.56, bkg_mean 239.06, aperture.area 28.27)
# ROI 2 initial (1086.8,939.0) → refined (1088.3,941.6)
# [DEBUG] In iterative: median=0.11, min=-19.83, max=20019.58
# ROI 3 initial (1206.8,939.0) → refined (1207.7,932.6)
# [DEBUG] In iterative: median=0.11, min=-19.83, max=20019.58
# [Info] Negative flux (-867.60) at r=2.0 for (1207.7,932.6); continuing. phot_table 2891.66, bkg_mean 299.15, aperture.area 12.57)
# [Info] Negative flux (-388.05) at r=3.0 for (1207.7,932.6); continuing. phot_table 6992.86, bkg_mean 261.05, aperture.area 28.27)
# [INFO] Using common aperture radius = 23.00 px, annulus outer radius = 32.00 px, minimum radii was 16.00
# ROI 0: flux=1025729.1, Bkg=13.04, RMS=5.56
# ROI 1: flux=1018645.4, Bkg=15.04, RMS=6.09
# ROI 2: flux=1107615.6, Bkg=17.79, RMS=5.64
# ROI 3: flux=1123304.0, Bkg=16.86, RMS=8.03
#
# Fluxes for AF969634.fits.gz:
#    I0=1025729.09, I90=1018645.39, I45=1107615.59, I135=1123304.05
# [Info] Detected 6 sources in defined ROIs.
#   ROI 1: x = 1169.59, y = 474.00
#   ROI 2: x = 960.57, y = 594.11
#   ROI 3: x = 987.07, y = 933.81
#   ROI 4: x = 875.96, y = 934.93
#   ROI 5: x = 1224.50, y = 935.45
#   ROI 6: x = 1113.31, y = 936.34
# ROI 0 initial (876.0,934.9) → refined (875.8,934.9)
# [DEBUG] In iterative: median=-0.07, min=-21.97, max=7627.80
# ROI 1 initial (996.0,934.9) → refined (995.1,928.9)
# [DEBUG] In iterative: median=-0.07, min=-21.97, max=7627.80
# [Info] Negative flux (-119.87) at r=2.0 for (995.1,928.9); continuing. phot_table 6251.32, bkg_mean 507.00, aperture.area 12.57)
# ROI 2 initial (1108.0,934.9) → refined (1108.9,938.7)
# [DEBUG] In iterative: median=-0.07, min=-21.97, max=7627.80
# ROI 3 initial (1228.0,934.9) → refined (1228.3,932.2)
# [DEBUG] In iterative: median=-0.07, min=-21.97, max=7627.80
# [Info] Negative flux (-1095.93) at r=2.0 for (1228.3,932.2); continuing. phot_table 26364.56, bkg_mean 2185.24, aperture.area 12.57)
# [INFO] Using common aperture radius = 22.00 px, annulus outer radius = 36.00 px, minimum radii was 18.00
# ROI 0: flux=680759.4, Bkg=16.63, RMS=5.26
# ROI 1: flux=682594.6, Bkg=19.78, RMS=6.60
# ROI 2: flux=603830.8, Bkg=19.04, RMS=6.13
# ROI 3: flux=621258.1, Bkg=18.08, RMS=6.31
#
# Fluxes for AF969635.fits.gz:
#    I0=680759.36, I90=682594.63, I45=603830.76, I135=621258.08
# [Info] Detected 5 sources in defined ROIs.
#   ROI 1: x = 1103.72, y = 646.32
#   ROI 2: x = 987.64, y = 935.00
#   ROI 3: x = 876.53, y = 936.13
#   ROI 4: x = 1224.60, y = 936.85
#   ROI 5: x = 1113.45, y = 937.82
# ROI 0 initial (876.5,936.1) → refined (877.0,935.5)
# [DEBUG] In iterative: median=-0.09, min=-20.50, max=53829.79
# ROI 1 initial (996.5,936.1) → refined (996.2,930.3)
# [DEBUG] In iterative: median=-0.09, min=-20.50, max=53829.79
# [Info] Negative flux (-817.75) at r=2.0 for (996.2,930.3); continuing. phot_table 7658.44, bkg_mean 674.51, aperture.area 12.57)
# ROI 2 initial (1108.5,936.1) → refined (1110.1,938.8)
# [DEBUG] In iterative: median=-0.09, min=-20.50, max=53829.79
# ROI 3 initial (1228.5,936.1) → refined (1229.6,932.7)
# [DEBUG] In iterative: median=-0.09, min=-20.50, max=53829.79
# [Info] Negative flux (-902.83) at r=2.0 for (1229.6,932.7); continuing. phot_table 16250.48, bkg_mean 1365.02, aperture.area 12.57)
# [Info] Negative flux (-1399.33) at r=3.0 for (1229.6,932.7); continuing. phot_table 37231.65, bkg_mean 1366.29, aperture.area 28.27)
# [Info] Negative flux (-688.58) at r=4.0 for (1229.6,932.7); continuing. phot_table 67386.54, bkg_mean 1354.31, aperture.area 50.27)
# [INFO] Using common aperture radius = 24.00 px, annulus outer radius = 40.00 px, minimum radii was 20.00
# ROI 0: flux=683315.5, Bkg=15.53, RMS=5.35
# ROI 1: flux=686770.4, Bkg=18.06, RMS=6.16
# ROI 2: flux=610680.2, Bkg=17.60, RMS=5.74
# ROI 3: flux=625727.7, Bkg=16.19, RMS=6.30
#
# Fluxes for AF969636.fits.gz:
#    I0=683315.52, I90=686770.39, I45=610680.21, I135=625727.68
# [Info] Detected 4 sources in defined ROIs.
#   ROI 1: x = 987.02, y = 935.42
#   ROI 2: x = 875.89, y = 936.53
#   ROI 3: x = 1224.07, y = 936.63
#   ROI 4: x = 1112.86, y = 937.53
# ROI 0 initial (875.9,936.5) → refined (875.5,936.8)
# [DEBUG] In iterative: median=-0.07, min=-20.31, max=6764.25
# ROI 1 initial (995.9,936.5) → refined (994.7,931.0)
# [DEBUG] In iterative: median=-0.07, min=-20.31, max=6764.25
# [Info] Negative flux (-203.53) at r=2.0 for (994.7,931.0); continuing. phot_table 8483.13, bkg_mean 691.26, aperture.area 12.57)
# ROI 2 initial (1107.9,936.5) → refined (1108.3,940.4)
# [DEBUG] In iterative: median=-0.07, min=-20.31, max=6764.25
# [Info] Negative flux (-1521.96) at r=2.0 for (1108.3,940.4); continuing. phot_table 24234.61, bkg_mean 2049.64, aperture.area 12.57)
# ROI 3 initial (1227.9,936.5) → refined (1227.6,933.9)
# [DEBUG] In iterative: median=-0.07, min=-20.31, max=6764.25
# [INFO] Using common aperture radius = 22.00 px, annulus outer radius = 38.00 px, minimum radii was 19.00
# ROI 0: flux=680850.3, Bkg=16.13, RMS=5.55
# ROI 1: flux=685677.0, Bkg=18.53, RMS=6.09
# ROI 2: flux=603347.0, Bkg=18.46, RMS=5.79
# ROI 3: flux=625014.2, Bkg=17.10, RMS=6.06
#
# Fluxes for AF969637.fits.gz:
#    I0=680850.29, I90=685676.96, I45=603346.97, I135=625014.22
# [Info] Detected 4 sources in defined ROIs.
#   ROI 1: x = 986.81, y = 935.14
#   ROI 2: x = 875.67, y = 936.25
#   ROI 3: x = 1224.48, y = 936.86
#   ROI 4: x = 1113.33, y = 937.76
# ROI 0 initial (875.7,936.3) → refined (876.1,935.6)
# [DEBUG] In iterative: median=-0.08, min=-20.12, max=8135.77
# ROI 1 initial (995.7,936.3) → refined (995.2,929.7)
# [DEBUG] In iterative: median=-0.08, min=-20.12, max=8135.77
# ROI 2 initial (1107.7,936.3) → refined (1109.3,940.0)
# [DEBUG] In iterative: median=-0.08, min=-20.12, max=8135.77
# [Info] Negative flux (-147.92) at r=2.0 for (1109.3,940.0); continuing. phot_table 30713.90, bkg_mean 2455.91, aperture.area 12.57)
# ROI 3 initial (1227.7,936.3) → refined (1228.7,933.0)
# [DEBUG] In iterative: median=-0.08, min=-20.12, max=8135.77
# [Info] Negative flux (-2493.32) at r=2.0 for (1228.7,933.0); continuing. phot_table 19809.65, bkg_mean 1774.81, aperture.area 12.57)
# [Info] Negative flux (-9618.69) at r=3.0 for (1228.7,933.0); continuing. phot_table 47595.16, bkg_mean 2023.53, aperture.area 28.27)
# [Info] Negative flux (-586.21) at r=4.0 for (1228.7,933.0); continuing. phot_table 90410.67, bkg_mean 1810.33, aperture.area 50.27)
# [INFO] Using common aperture radius = 22.00 px, annulus outer radius = 34.00 px, minimum radii was 17.00
# ROI 0: flux=682271.9, Bkg=17.22, RMS=5.70
# ROI 1: flux=683971.2, Bkg=20.45, RMS=6.94
# ROI 2: flux=606505.0, Bkg=19.72, RMS=6.08
# ROI 3: flux=626385.4, Bkg=18.29, RMS=6.08
#
# Fluxes for AF969638.fits.gz:
#    I0=682271.86, I90=683971.23, I45=606504.99, I135=626385.36
# [Info] Detected 4 sources in defined ROIs.
#   ROI 1: x = 986.32, y = 935.56
#   ROI 2: x = 875.18, y = 936.67
#   ROI 3: x = 1224.19, y = 936.82
#   ROI 4: x = 1112.97, y = 937.71
# ROI 0 initial (875.2,936.7) → refined (874.6,937.1)
# [DEBUG] In iterative: median=-0.07, min=-21.40, max=9722.91
# ROI 1 initial (995.2,936.7) → refined (993.8,930.6)
# [DEBUG] In iterative: median=-0.07, min=-21.40, max=9722.91
# [Info] Negative flux (-1362.60) at r=2.0 for (993.8,930.6); continuing. phot_table 5686.57, bkg_mean 560.95, aperture.area 12.57)
# ROI 2 initial (1107.2,936.7) → refined (1107.5,941.5)
# [DEBUG] In iterative: median=-0.07, min=-21.40, max=9722.91
# [Info] Negative flux (-1816.54) at r=2.0 for (1107.5,941.5); continuing. phot_table 12660.24, bkg_mean 1152.03, aperture.area 12.57)
# ROI 3 initial (1227.2,936.7) → refined (1226.8,934.6)
# [DEBUG] In iterative: median=-0.07, min=-21.40, max=9722.91
# [INFO] Using common aperture radius = 21.00 px, annulus outer radius = 34.00 px, minimum radii was 17.00
# ROI 0: flux=679199.0, Bkg=17.64, RMS=5.66
# ROI 1: flux=684688.4, Bkg=20.34, RMS=6.98
# ROI 2: flux=601493.6, Bkg=19.52, RMS=6.27
# ROI 3: flux=625347.8, Bkg=18.20, RMS=6.04
#
# Fluxes for AF969639.fits.gz:
#    I0=679199.02, I90=684688.42, I45=601493.62, I135=625347.75
# [Info] Detected 4 sources in defined ROIs.
#   ROI 1: x = 986.11, y = 934.70
#   ROI 2: x = 874.97, y = 935.84
#   ROI 3: x = 1224.00, y = 936.43
#   ROI 4: x = 1112.84, y = 937.31
# ROI 0 initial (875.0,935.8) → refined (874.8,935.9)
# [DEBUG] In iterative: median=-0.07, min=-19.54, max=7896.75
# ROI 1 initial (995.0,935.8) → refined (994.0,929.9)
# [DEBUG] In iterative: median=-0.07, min=-19.54, max=7896.75
# [Info] Negative flux (-852.45) at r=2.0 for (994.0,929.9); continuing. phot_table 6396.50, bkg_mean 576.85, aperture.area 12.57)
# ROI 2 initial (1107.0,935.8) → refined (1107.9,940.1)
# [DEBUG] In iterative: median=-0.07, min=-19.54, max=7896.75
# [Info] Negative flux (-2037.16) at r=2.0 for (1107.9,940.1); continuing. phot_table 21431.26, bkg_mean 1867.56, aperture.area 12.57)
# [Info] Negative flux (-2290.58) at r=3.0 for (1107.9,940.1); continuing. phot_table 49624.17, bkg_mean 1836.11, aperture.area 28.27)
# ROI 3 initial (1227.0,935.8) → refined (1227.3,933.5)
# [DEBUG] In iterative: median=-0.07, min=-19.54, max=7896.75
# [INFO] Using common aperture radius = 22.00 px, annulus outer radius = 36.00 px, minimum radii was 18.00
# ROI 0: flux=680224.8, Bkg=16.88, RMS=5.60
# ROI 1: flux=684839.4, Bkg=19.38, RMS=6.50
# ROI 2: flux=603164.2, Bkg=19.20, RMS=6.14
# ROI 3: flux=624522.7, Bkg=17.86, RMS=6.57
#
# Fluxes for AF969640.fits.gz:
#    I0=680224.75, I90=684839.40, I45=603164.24, I135=624522.75
# [Info] Detected 5 sources in defined ROIs.
#   ROI 1: x = 1134.09, y = 782.90
#   ROI 2: x = 987.53, y = 934.36
#   ROI 3: x = 876.39, y = 935.48
#   ROI 4: x = 1225.06, y = 935.69
#   ROI 5: x = 1113.89, y = 936.57
# ROI 0 initial (876.4,935.5) → refined (876.3,935.3)
# [DEBUG] In iterative: median=-0.07, min=-19.74, max=10161.57
# ROI 1 initial (996.4,935.5) → refined (995.5,928.7)
# [DEBUG] In iterative: median=-0.07, min=-19.74, max=10161.57
# [Info] Negative flux (-826.48) at r=2.0 for (995.5,928.7); continuing. phot_table 4139.82, bkg_mean 395.21, aperture.area 12.57)
# ROI 2 initial (1108.4,935.5) → refined (1109.2,939.4)
# [DEBUG] In iterative: median=-0.07, min=-19.74, max=10161.57
# ...
#   ROI 1: x = 982.85, y = 922.91
#   ROI 2: x = 1214.74, y = 922.24
#   ROI 3: x = 875.04, y = 924.07
#   ROI 4: x = 1106.79, y = 923.13
# ROI 0 initial (875.0,924.1) → refined (875.0,924.0)
# [DEBUG] In iterative: median=0.13, min=-18.79, max=18842.35
# ROI 1 initial (995.0,924.1) → refined (993.9,916.9)
# [DEBUG] In iterative: median=0.13, min=-18.79, max=18842.35
# [Info] Negative flux (-214.57) at r=2.0 for (993.9,916.9); continuing. phot_table 1093.77, bkg_mean 104.11, aperture.area 12.57)
# [Info] Negative flux (-225.77) at r=3.0 for (993.9,916.9); continuing. phot_table 2664.34, bkg_mean 102.22, aperture.area 28.27)
# ROI 2 initial (1107.0,924.1) → refined (1106.1,923.8)
# [DEBUG] In iterative: median=0.13, min=-18.79, max=18842.35
# ROI 3 initial (1227.0,924.1) → refined (1224.3,916.0)
# [DEBUG] In iterative: median=0.13, min=-18.79, max=18842.35
# [Info] Negative flux (-399.27) at r=2.0 for (1224.3,916.0); continuing. phot_table 1702.07, bkg_mean 167.22, aperture.area 12.57)
# [INFO] Using common aperture radius = 23.00 px, annulus outer radius = 28.00 px, minimum radii was 14.00
# ROI 0: flux=550820.0, Bkg=3.61, RMS=4.30
# ROI 1: flux=542743.1, Bkg=4.13, RMS=4.67
# ROI 2: flux=626732.7, Bkg=4.52, RMS=4.04
# ROI 3: flux=635382.2, Bkg=4.40, RMS=4.64
#
# Fluxes for AF969719.fits.gz:
#    I0=550820.01, I90=542743.09, I45=626732.66, I135=635382.16
# [Info] Detected 4 sources in defined ROIs.
#   ROI 1: x = 983.42, y = 922.29
#   ROI 2: x = 1216.49, y = 922.08
#   ROI 3: x = 875.60, y = 923.39
#   ROI 4: x = 1108.56, y = 922.96
# ROI 0 initial (875.6,923.4) → refined (876.3,922.6)
# [DEBUG] In iterative: median=0.13, min=-18.84, max=18949.30
# ROI 1 initial (995.6,923.4) → refined (994.9,916.0)
# [DEBUG] In iterative: median=0.13, min=-18.84, max=18949.30
# [Info] Negative flux (-207.77) at r=2.0 for (994.9,916.0); continuing. phot_table 1160.11, bkg_mean 108.85, aperture.area 12.57)
# [Info] Negative flux (-569.49) at r=3.0 for (994.9,916.0); continuing. phot_table 2811.10, bkg_mean 119.56, aperture.area 28.27)
# ROI 2 initial (1107.6,923.4) → refined (1107.9,923.4)
# [DEBUG] In iterative: median=0.13, min=-18.84, max=18949.30
# ROI 3 initial (1227.6,923.4) → refined (1226.4,915.2)
# [DEBUG] In iterative: median=0.13, min=-18.84, max=18949.30
# [Info] Negative flux (-121.73) at r=2.0 for (1226.4,915.2); continuing. phot_table 1509.67, bkg_mean 129.82, aperture.area 12.57)
# [INFO] Using common aperture radius = 23.00 px, annulus outer radius = 28.00 px, minimum radii was 14.00
# ROI 0: flux=558290.7, Bkg=3.90, RMS=3.91
# ROI 1: flux=548368.0, Bkg=5.10, RMS=5.19
# ROI 2: flux=637005.7, Bkg=4.15, RMS=4.15
# ROI 3: flux=642793.9, Bkg=4.42, RMS=5.03
#
# Fluxes for AF969720.fits.gz:
#    I0=558290.71, I90=548368.04, I45=637005.70, I135=642793.94
# [Info] Detected 4 sources in defined ROIs.
#   ROI 1: x = 983.66, y = 922.32
#   ROI 2: x = 1215.71, y = 921.87
#   ROI 3: x = 875.84, y = 923.46
#   ROI 4: x = 1107.83, y = 922.77
# ROI 0 initial (875.8,923.5) → refined (876.4,922.8)
# [DEBUG] In iterative: median=0.12, min=-18.84, max=19586.34
# ROI 1 initial (995.8,923.5) → refined (995.4,915.9)
# [DEBUG] In iterative: median=0.12, min=-18.84, max=19586.34
# ROI 2 initial (1107.8,923.5) → refined (1107.7,922.8)
# [DEBUG] In iterative: median=0.12, min=-18.84, max=19586.34
# ROI 3 initial (1227.8,923.5) → refined (1226.2,915.0)
# [DEBUG] In iterative: median=0.12, min=-18.84, max=19586.34
# [Info] Negative flux (-87.36) at r=2.0 for (1226.2,915.0); continuing. phot_table 1094.05, bkg_mean 94.01, aperture.area 12.57)
# [INFO] Using common aperture radius = 23.00 px, annulus outer radius = 28.00 px, minimum radii was 14.00
# ROI 0: flux=552085.2, Bkg=3.15, RMS=4.29
# ROI 1: flux=539955.2, Bkg=4.80, RMS=4.91
# ROI 2: flux=628869.7, Bkg=4.21, RMS=4.16
# ROI 3: flux=631819.2, Bkg=4.86, RMS=5.08
#
# Fluxes for AF969721.fits.gz:
#    I0=552085.16, I90=539955.18, I45=628869.65, I135=631819.21
# [Info] Detected 4 sources in defined ROIs.
#   ROI 1: x = 983.95, y = 922.95
#   ROI 2: x = 1216.15, y = 922.95
#   ROI 3: x = 876.13, y = 924.07
#   ROI 4: x = 1108.28, y = 923.80
# ROI 0 initial (876.1,924.1) → refined (876.0,924.1)
# [DEBUG] In iterative: median=0.15, min=-19.53, max=17859.42
# ROI 1 initial (996.1,924.1) → refined (994.5,916.7)
# [DEBUG] In iterative: median=0.15, min=-19.53, max=17859.42
# [Info] Negative flux (-347.36) at r=2.0 for (994.5,916.7); continuing. phot_table 1272.73, bkg_mean 128.92, aperture.area 12.57)
# [Info] Negative flux (-121.72) at r=3.0 for (994.5,916.7); continuing. phot_table 3173.72, bkg_mean 116.55, aperture.area 28.27)
# ROI 2 initial (1108.1,924.1) → refined (1107.8,924.2)
# [DEBUG] In iterative: median=0.15, min=-19.53, max=17859.42
# ROI 3 initial (1228.1,924.1) → refined (1226.0,916.1)
# [DEBUG] In iterative: median=0.15, min=-19.53, max=17859.42
# [Info] Negative flux (-140.22) at r=2.0 for (1226.0,916.1); continuing. phot_table 1176.68, bkg_mean 104.79, aperture.area 12.57)
# [INFO] Using common aperture radius = 22.00 px, annulus outer radius = 28.00 px, minimum radii was 14.00
# ROI 0: flux=554194.7, Bkg=3.77, RMS=4.06
# ROI 1: flux=546463.8, Bkg=4.73, RMS=4.57
# ROI 2: flux=633892.0, Bkg=4.90, RMS=4.07
# ROI 3: flux=638212.1, Bkg=4.99, RMS=5.04
#
# Fluxes for AF969722.fits.gz:
#    I0=554194.73, I90=546463.84, I45=633891.96, I135=638212.10
# [Info] Detected 4 sources in defined ROIs.
#   ROI 1: x = 981.93, y = 921.96
#   ROI 2: x = 1215.74, y = 921.79
#   ROI 3: x = 874.08, y = 923.06
#   ROI 4: x = 1107.84, y = 922.67
# ROI 0 initial (874.1,923.1) → refined (874.0,923.1)
# [DEBUG] In iterative: median=0.13, min=-18.95, max=17252.48
# ROI 1 initial (994.1,923.1) → refined (992.8,915.7)
# [DEBUG] In iterative: median=0.13, min=-18.95, max=17252.48
# [Info] Negative flux (-264.35) at r=2.0 for (992.8,915.7); continuing. phot_table 965.87, bkg_mean 97.90, aperture.area 12.57)
# [Info] Negative flux (-173.50) at r=3.0 for (992.8,915.7); continuing. phot_table 2391.46, bkg_mean 90.72, aperture.area 28.27)
# ROI 2 initial (1106.1,923.1) → refined (1105.7,924.6)
# [DEBUG] In iterative: median=0.13, min=-18.95, max=17252.48
# ROI 3 initial (1226.1,923.1) → refined (1223.9,915.3)
# [DEBUG] In iterative: median=0.13, min=-18.95, max=17252.48
# [Info] Negative flux (-261.22) at r=2.0 for (1223.9,915.3); continuing. phot_table 2487.47, bkg_mean 218.73, aperture.area 12.57)
# [INFO] Using common aperture radius = 22.00 px, annulus outer radius = 30.00 px, minimum radii was 15.00
# ROI 0: flux=547367.8, Bkg=4.13, RMS=4.21
# ROI 1: flux=538638.7, Bkg=4.91, RMS=5.17
# ROI 2: flux=627458.9, Bkg=4.26, RMS=4.18
# ROI 3: flux=632900.1, Bkg=5.03, RMS=5.37
#
# Fluxes for AF969723.fits.gz:
#    I0=547367.76, I90=538638.70, I45=627458.93, I135=632900.15
# [Info] Detected 4 sources in defined ROIs.
#   ROI 1: x = 981.86, y = 921.94
#   ROI 2: x = 1215.73, y = 922.42
#   ROI 3: x = 874.04, y = 923.08
#   ROI 4: x = 1107.81, y = 923.33
# ROI 0 initial (874.0,923.1) → refined (874.0,923.0)
# [DEBUG] In iterative: median=0.13, min=-19.60, max=19007.53
# ROI 1 initial (994.0,923.1) → refined (992.9,915.8)
# [DEBUG] In iterative: median=0.13, min=-19.60, max=19007.53
# [Info] Negative flux (-190.18) at r=2.0 for (992.9,915.8); continuing. phot_table 1068.64, bkg_mean 100.17, aperture.area 12.57)
# [Info] Negative flux (-387.15) at r=3.0 for (992.9,915.8); continuing. phot_table 2559.11, bkg_mean 104.20, aperture.area 28.27)
# [Info] Negative flux (-12.68) at r=4.0 for (992.9,915.8); continuing. phot_table 4896.48, bkg_mean 97.66, aperture.area 50.27)
# ROI 2 initial (1106.0,923.1) → refined (1106.2,924.6)
# [DEBUG] In iterative: median=0.13, min=-19.60, max=19007.53
# ROI 3 initial (1226.0,923.1) → refined (1224.8,915.1)
# [DEBUG] In iterative: median=0.13, min=-19.60, max=19007.53
# [Info] Negative flux (-37.30) at r=2.0 for (1224.8,915.1); continuing. phot_table 1440.69, bkg_mean 117.61, aperture.area 12.57)
# [INFO] Using common aperture radius = 22.00 px, annulus outer radius = 28.00 px, minimum radii was 14.00
# ROI 0: flux=555757.6, Bkg=3.57, RMS=4.06
# ROI 1: flux=547463.4, Bkg=5.28, RMS=5.04
# ROI 2: flux=638282.6, Bkg=4.19, RMS=3.96
# ROI 3: flux=640549.6, Bkg=5.19, RMS=5.56
#
# Fluxes for AF969724.fits.gz:
#    I0=555757.64, I90=547463.42, I45=638282.57, I135=640549.64
# [Info] Detected 4 sources in defined ROIs.
#   ROI 1: x = 983.85, y = 921.45
#   ROI 2: x = 1216.04, y = 920.92
#   ROI 3: x = 1108.09, y = 921.78
#   ROI 4: x = 876.05, y = 922.59
# ROI 0 initial (876.0,922.6) → refined (875.6,923.0)
# [DEBUG] In iterative: median=0.15, min=-18.42, max=19071.20
# ROI 1 initial (996.0,922.6) → refined (994.5,915.7)
# [DEBUG] In iterative: median=0.15, min=-18.42, max=19071.20
# [Info] Negative flux (-56.94) at r=2.0 for (994.5,915.7); continuing. phot_table 1318.14, bkg_mean 109.43, aperture.area 12.57)
# ROI 2 initial (1108.0,922.6) → refined (1106.8,923.0)
# [DEBUG] In iterative: median=0.15, min=-18.42, max=19071.20
# ROI 3 initial (1228.0,922.6) → refined (1225.3,914.9)
# [DEBUG] In iterative: median=0.15, min=-18.42, max=19071.20
# [Info] Negative flux (-212.77) at r=2.0 for (1225.3,914.9); continuing. phot_table 1636.18, bkg_mean 147.13, aperture.area 12.57)
# [INFO] Using common aperture radius = 22.00 px, annulus outer radius = 28.00 px, minimum radii was 14.00
# ROI 0: flux=549690.8, Bkg=3.72, RMS=4.24
# ROI 1: flux=541731.5, Bkg=5.11, RMS=4.61
# ROI 2: flux=626767.6, Bkg=4.30, RMS=4.31
# ROI 3: flux=635158.5, Bkg=4.35, RMS=5.16
#
# Fluxes for AF969725.fits.gz:
#    I0=549690.78, I90=541731.51, I45=626767.61, I135=635158.55
# [Info] Detected 4 sources in defined ROIs.
#   ROI 1: x = 982.90, y = 921.56
#   ROI 2: x = 1216.18, y = 920.85
#   ROI 3: x = 875.11, y = 922.69
#   ROI 4: x = 1108.23, y = 921.68
# ROI 0 initial (875.1,922.7) → refined (874.7,923.1)
# [DEBUG] In iterative: median=0.15, min=-17.86, max=19529.23
# ROI 1 initial (995.1,922.7) → refined (993.7,915.8)
# [DEBUG] In iterative: median=0.15, min=-17.86, max=19529.23
# [Info] Negative flux (-260.16) at r=2.0 for (993.7,915.8); continuing. phot_table 1501.11, bkg_mean 140.16, aperture.area 12.57)
# [Info] Negative flux (-216.39) at r=3.0 for (993.7,915.8); continuing. phot_table 3554.73, bkg_mean 133.38, aperture.area 28.27)
# ROI 2 initial (1107.1,922.7) → refined (1105.7,924.0)
# [DEBUG] In iterative: median=0.15, min=-17.86, max=19529.23
# ROI 3 initial (1227.1,922.7) → refined (1224.2,915.4)
# [DEBUG] In iterative: median=0.15, min=-17.86, max=19529.23
# [Info] Negative flux (-1280.19) at r=2.0 for (1224.2,915.4); continuing. phot_table 3238.53, bkg_mean 359.59, aperture.area 12.57)
# [INFO] Using common aperture radius = 22.00 px, annulus outer radius = 30.00 px, minimum radii was 15.00
# ROI 0: flux=559957.9, Bkg=3.60, RMS=4.35
# ROI 1: flux=550589.1, Bkg=5.56, RMS=5.88
# ROI 2: flux=637645.5, Bkg=4.12, RMS=4.28
# ROI 3: flux=646382.1, Bkg=5.14, RMS=5.06
#
# Fluxes for AF969726.fits.gz:
#    I0=559957.86, I90=550589.07, I45=637645.52, I135=646382.09
# [Info] Detected 4 sources in defined ROIs.
#   ROI 1: x = 982.46, y = 920.65
#   ROI 2: x = 1217.00, y = 920.07
#   ROI 3: x = 874.65, y = 921.77
#   ROI 4: x = 1109.07, y = 920.95
# ROI 0 initial (874.6,921.8) → refined (874.7,921.6)
# [DEBUG] In iterative: median=0.14, min=-18.44, max=23875.53
# ROI 1 initial (994.6,921.8) → refined (993.4,915.0)
# [DEBUG] In iterative: median=0.14, min=-18.44, max=23875.53
# [Info] Negative flux (-354.32) at r=2.0 for (993.4,915.0); continuing. phot_table 1089.85, bkg_mean 114.92, aperture.area 12.57)
# [Info] Negative flux (-811.35) at r=3.0 for (993.4,915.0); continuing. phot_table 2672.84, bkg_mean 123.23, aperture.area 28.27)
# [Info] Negative flux (-169.73) at r=4.0 for (993.4,915.0); continuing. phot_table 5314.61, bkg_mean 109.11, aperture.area 50.27)
# ROI 2 initial (1106.6,921.8) → refined (1106.0,923.8)
# [DEBUG] In iterative: median=0.14, min=-18.44, max=23875.53
# ROI 3 initial (1226.6,921.8) → refined (1224.4,914.4)
# [DEBUG] In iterative: median=0.14, min=-18.44, max=23875.53
# [INFO] Using common aperture radius = 22.00 px, annulus outer radius = 30.00 px, minimum radii was 15.00
# ROI 0: flux=548385.9, Bkg=3.71, RMS=4.47
# ROI 1: flux=540429.2, Bkg=4.98, RMS=5.24
# ROI 2: flux=628725.7, Bkg=4.35, RMS=4.11
# ROI 3: flux=640334.4, Bkg=4.84, RMS=4.88
#
# Fluxes for AF969727.fits.gz:
#    I0=548385.94, I90=540429.20, I45=628725.68, I135=640334.35
# [Info] Detected 4 sources in defined ROIs.
#   ROI 1: x = 981.96, y = 921.63
#   ROI 2: x = 874.15, y = 922.76
#   ROI 3: x = 1215.76, y = 921.57
#   ROI 4: x = 1107.83, y = 922.43
# ROI 0 initial (874.1,922.8) → refined (873.7,923.1)
# [DEBUG] In iterative: median=0.14, min=-18.71, max=24684.22
# ROI 1 initial (994.1,922.8) → refined (992.8,915.6)
# [DEBUG] In iterative: median=0.14, min=-18.71, max=24684.22
# [Info] Negative flux (-260.87) at r=2.0 for (992.8,915.6); continuing. phot_table 1018.03, bkg_mean 101.77, aperture.area 12.57)
# [Info] Negative flux (-652.94) at r=3.0 for (992.8,915.6); continuing. phot_table 2461.52, bkg_mean 110.15, aperture.area 28.27)
# ROI 2 initial (1106.1,922.8) → refined (1105.4,924.6)
# [DEBUG] In iterative: median=0.14, min=-18.71, max=24684.22
# ROI 3 initial (1226.1,922.8) → refined (1224.2,915.2)
# [DEBUG] In iterative: median=0.14, min=-18.71, max=24684.22
# [Info] Negative flux (-98.39) at r=2.0 for (1224.2,915.2); continuing. phot_table 1820.62, bkg_mean 152.71, aperture.area 12.57)
# [INFO] Using common aperture radius = 22.00 px, annulus outer radius = 28.00 px, minimum radii was 14.00
# ROI 0: flux=561582.7, Bkg=3.77, RMS=3.99
# ROI 1: flux=553008.0, Bkg=5.35, RMS=5.40
# ROI 2: flux=641729.5, Bkg=4.52, RMS=4.13
# ROI 3: flux=648000.0, Bkg=4.94, RMS=4.79
#
# Fluxes for AF969728.fits.gz:
#    I0=561582.65, I90=553008.03, I45=641729.51, I135=647999.98
# [Info] Detected 4 sources in defined ROIs.
#   ROI 1: x = 979.98, y = 926.51
#   ROI 2: x = 871.20, y = 927.65
#   ROI 3: x = 1212.78, y = 927.38
#   ROI 4: x = 1103.99, y = 928.27
# ROI 0 initial (871.2,927.6) → refined (870.6,928.1)
# [DEBUG] In iterative: median=0.09, min=-19.22, max=30570.64
# ROI 1 initial (991.2,927.6) → refined (989.7,920.6)
# [DEBUG] In iterative: median=0.09, min=-19.22, max=30570.64
# [Info] Negative flux (-512.32) at r=2.0 for (989.7,920.6); continuing. phot_table 3163.28, bkg_mean 292.49, aperture.area 12.57)
# ROI 2 initial (1103.2,927.6) → refined (1103.2,928.8)
# [DEBUG] In iterative: median=0.09, min=-19.22, max=30570.64
# ROI 3 initial (1223.2,927.6) → refined (1222.2,920.5)
# [DEBUG] In iterative: median=0.09, min=-19.22, max=30570.64
# [Info] Negative flux (-106.69) at r=2.0 for (1222.2,920.5); continuing. phot_table 2550.68, bkg_mean 211.47, aperture.area 12.57)
# [INFO] Using common aperture radius = 22.00 px, annulus outer radius = 30.00 px, minimum radii was 15.00
# ROI 0: flux=1016236.6, Bkg=14.35, RMS=5.30
# ROI 1: flux=1011662.0, Bkg=16.19, RMS=6.45
# ROI 2: flux=1126612.9, Bkg=18.53, RMS=5.78
# ROI 3: flux=1138813.3, Bkg=18.80, RMS=8.64
#
# Fluxes for AF969729.fits.gz:
#    I0=1016236.59, I90=1011662.02, I45=1126612.86, I135=1138813.32
# [Info] Detected 4 sources in defined ROIs.
#   ROI 1: x = 978.95, y = 926.93
#   ROI 2: x = 870.15, y = 928.06
#   ROI 3: x = 1212.73, y = 926.97
#   ROI 4: x = 1103.90, y = 927.84
# ROI 0 initial (870.1,928.1) → refined (870.0,928.1)
# [DEBUG] In iterative: median=0.09, min=-18.37, max=36754.57
# ROI 1 initial (990.1,928.1) → refined (988.6,920.8)
# [DEBUG] In iterative: median=0.09, min=-18.37, max=36754.57
# [Info] Negative flux (-274.22) at r=2.0 for (988.6,920.8); continuing. phot_table 3520.24, bkg_mean 301.95, aperture.area 12.57)
# ROI 2 initial (1102.1,928.1) → refined (1101.8,929.7)
# [DEBUG] In iterative: median=0.09, min=-18.37, max=36754.57
# ROI 3 initial (1222.1,928.1) → refined (1220.7,920.6)
# [DEBUG] In iterative: median=0.09, min=-18.37, max=36754.57
# [Info] Negative flux (-641.97) at r=2.0 for (1220.7,920.6); continuing. phot_table 4093.31, bkg_mean 376.82, aperture.area 12.57)
# [INFO] Using common aperture radius = 22.00 px, annulus outer radius = 30.00 px, minimum radii was 15.00
# ROI 0: flux=1021554.2, Bkg=14.44, RMS=5.90
# ROI 1: flux=1016347.2, Bkg=16.65, RMS=5.90
# ROI 2: flux=1134376.3, Bkg=18.37, RMS=5.31
# ROI 3: flux=1152818.4, Bkg=18.50, RMS=8.23
#
# Fluxes for AF969730.fits.gz:
#    I0=1021554.24, I90=1016347.21, I45=1134376.32, I135=1152818.35
# saving results
